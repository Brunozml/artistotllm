# %%
import pandas as pd
from transformers import pipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

model_id = "Qwen/Qwen3-4B"          # or any 8-B variant, e.g. -AWQ, -FP8, GGUF etc.
tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
model     = AutoModelForCausalLM.from_pretrained(
               model_id,
               device_map="auto",           # GPU if you have one
               torch_dtype="auto"           # fp16/bf16 automatically
           )
generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    device_map="auto"
)

# %% [markdown]
# ### Text Generation

# %%
import os
import re

nlp_results = pd.DataFrame(columns=['Author', 'Title', 'y_train', 'y_pred', 'y_test'])

def remove_prefix(original, full):
    if full.startswith(original):
        return full[len(original):].lstrip()  # Remove leading spaces/newlines
    else:
        raise ValueError("The first text is not a prefix of the second.")

def split_text_by_sentences(text, word_limit):
    # Split text into sentences
    sentences = re.split(r'(?<=[.!?])\s+', text)
    train_text = ''
    word_count = 0

    for sentence in sentences:
        sentence_words = sentence.split()
        if word_count + len(sentence_words) > word_limit:
            break
        train_text += sentence + ' '
        word_count += len(sentence_words)

    # Now get the next 500 words after the train_text
    remaining_text = text[len(train_text):].strip()
    next_words = ' '.join(remaining_text.split()[:500])

    return train_text.strip(), next_words.strip()
base_path = "./"
authors = ["Mark_Twain", "Paul Graham", "Paul Krugman"]

for author in authors:
    folder_path = os.path.join(base_path, author)
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-16') as f:
                text = f.read()
                train_text, test_text = split_text_by_sentences(text, 500)
                # Do whatever you want with train_text and test_text
                print(f'Processed {filename} from {author}')
                pred = generator(
                    train_text,
                    # generation control
                    max_new_tokens=500,      # ← exactly the number you asked for
                    temperature=0.8,         # creativity (0–2); lower is safer
                    top_p=0.9,               # nucleus sampling
                    do_sample=True,          # sampling instead of greedy
                    eos_token_id=tokenizer.eos_token_id,   # stop at end-of-text if it appears
                )
                y_pred = pred[0]["generated_text"]
                result = remove_prefix(train_text, y_pred)
                new_row = pd.DataFrame([{'Author': author, 'Title': filename, 'y_pred': result, 'y_train': train_text, 'y_test': test_text}])
                nlp_results = pd.concat([nlp_results, new_row], ignore_index=True)

                print(nlp_results.shape)
                print(nlp_results)
# Out:
# Processed THE MAN THAT CORRUPTED HADLEYBURG.txt from Mark_Twain
# (1, 5)
#        Author                                  Title  \
# 0  Mark_Twain  THE MAN THAT CORRUPTED HADLEYBURG.txt
#
#                                              y_train  \
# 0  THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
#
#                                               y_pred  \
# 0  He made a\ntrip to Hadleyburg and found it the...
#
#                                               y_test
# 0  joy. He began to form a plan at once, saying t...
# Processed To the Person Sitting in Darkness.txt from Mark_Twain
# (2, 5)
#        Author                                  Title  \
# 0  Mark_Twain  THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1  Mark_Twain  To the Person Sitting in Darkness.txt
#
#                                              y_train  \
# 0  THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1  TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
#
#                                               y_pred  \
# 0  He made a\ntrip to Hadleyburg and found it the...
# 1  And\nthere is more of it. The People who Sit i...
#
#                                               y_test
# 0  joy. He began to form a plan at once, saying t...
# 1  Game. It shows that these new players of it ar...
# Processed Life on the Mississippi.txt from Mark_Twain
# (3, 5)
#        Author                                  Title  \
# 0  Mark_Twain  THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1  Mark_Twain  To the Person Sitting in Darkness.txt
# 2  Mark_Twain            Life on the Mississippi.txt
#
#                                              y_train  \
# 0  THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1  TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2  Produced by David Widger. Earliest PG text edi...
#
#                                               y_pred  \
# 0  He made a\ntrip to Hadleyburg and found it the...
# 1  And\nthere is more of it. The People who Sit i...
# 2  A New Plan.--A Little Tact.--The Mayor is\nHir...
#
#                                               y_test
# 0  joy. He began to form a plan at once, saying t...
# 1  Game. It shows that these new players of it ar...
# 2  rd. CHAPTER XXIII. Old French Settlements.--We...
# Processed KING LEOPOLD’S SOLILOQUY.txt from Mark_Twain
# (4, 5)
#        Author                                  Title  \
# 0  Mark_Twain  THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1  Mark_Twain  To the Person Sitting in Darkness.txt
# 2  Mark_Twain            Life on the Mississippi.txt
# 3  Mark_Twain           KING LEOPOLD’S SOLILOQUY.txt
#
#                                              y_train  \
# 0  THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1  TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2  Produced by David Widger. Earliest PG text edi...
# 3  KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
#
#                                               y_pred  \
# 0  He made a\ntrip to Hadleyburg and found it the...
# 1  And\nthere is more of it. The People who Sit i...
# 2  A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3  They\nare saying that I have a secret, a secre...
#
#                                               y_test
# 0  joy. He began to form a plan at once, saying t...
# 1  Game. It shows that these new players of it ar...
# 2  rd. CHAPTER XXIII. Old French Settlements.--We...
# 3  hen uttered against a king. Miscreants—they ar...
# Processed A Horse's Tale.txt from Mark_Twain
# (5, 5)
#        Author                                  Title  \
# 0  Mark_Twain  THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1  Mark_Twain  To the Person Sitting in Darkness.txt
# 2  Mark_Twain            Life on the Mississippi.txt
# 3  Mark_Twain           KING LEOPOLD’S SOLILOQUY.txt
# 4  Mark_Twain                     A Horse's Tale.txt
#
#                                              y_train  \
# 0  THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1  TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2  Produced by David Widger. Earliest PG text edi...
# 3  KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4  A Horse’s Tale\n\n\n                          ...
#
#                                               y_pred  \
# 0  He made a\ntrip to Hadleyburg and found it the...
# 1  And\nthere is more of it. The People who Sit i...
# 2  A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3  They\nare saying that I have a secret, a secre...
# 4  * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
#
#                                               y_test
# 0  joy. He began to form a plan at once, saying t...
# 1  Game. It shows that these new players of it ar...
# 2  rd. CHAPTER XXIII. Old French Settlements.--We...
# 3  hen uttered against a king. Miscreants—they ar...
# 4  rian will correct these defects.” The cats in ...
# Processed 1601 Conversation as it was by the Social Fireside in the Time of the Tudors.txt from Mark_Twain
# (6, 5)
#        Author                                              Title  \
# 0  Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1  Mark_Twain              To the Person Sitting in Darkness.txt
# 2  Mark_Twain                        Life on the Mississippi.txt
# 3  Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4  Mark_Twain                                 A Horse's Tale.txt
# 5  Mark_Twain  1601 Conversation as it was by the Social Fire...
#
#                                              y_train  \
# 0  THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1  TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2  Produced by David Widger. Earliest PG text edi...
# 3  KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4  A Horse’s Tale\n\n\n                          ...
# 5  1601\n\nConversation as it was by the Social F...
#
#                                               y_pred  \
# 0  He made a\ntrip to Hadleyburg and found it the...
# 1  And\nthere is more of it. The People who Sit i...
# 2  A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3  They\nare saying that I have a secret, a secre...
# 4  * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5  The first edition of it was published\nin 1880...
#
#                                               y_test
# 0  joy. He began to form a plan at once, saying t...
# 1  Game. It shows that these new players of it ar...
# 2  rd. CHAPTER XXIII. Old French Settlements.--We...
# 3  hen uttered against a king. Miscreants—they ar...
# 4  rian will correct these defects.” The cats in ...
# 5  601. The piece is a supposititious conversatio...
# Processed Following the Equator A Journey Around the World.txt from Mark_Twain
# (7, 5)
#        Author                                              Title  \
# 0  Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1  Mark_Twain              To the Person Sitting in Darkness.txt
# 2  Mark_Twain                        Life on the Mississippi.txt
# 3  Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4  Mark_Twain                                 A Horse's Tale.txt
# 5  Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6  Mark_Twain  Following the Equator A Journey Around the Wor...
#
#                                              y_train  \
# 0  THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1  TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2  Produced by David Widger. Earliest PG text edi...
# 3  KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4  A Horse’s Tale\n\n\n                          ...
# 5  1601\n\nConversation as it was by the Social F...
# 6  Produced by David Widger\n\n\n\n\n\n          ...
#
#                                               y_pred  \
# 0  He made a\ntrip to Hadleyburg and found it the...
# 1  And\nthere is more of it. The People who Sit i...
# 2  A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3  They\nare saying that I have a secret, a secre...
# 4  * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5  The first edition of it was published\nin 1880...
# 6  The  Australian Desert--The  Great Barrier Ree...
#
#                                               y_test
# 0  joy. He began to form a plan at once, saying t...
# 1  Game. It shows that these new players of it ar...
# 2  rd. CHAPTER XXIII. Old French Settlements.--We...
# 3  hen uttered against a king. Miscreants—they ar...
# 4  rian will correct these defects.” The cats in ...
# 5  601. The piece is a supposititious conversatio...
# 6  shing--Cecil Rhodes' Shark and his First Fortu...
# Processed The Entire Project Gutenberg Works of Mark Twain.txt from Mark_Twain
# (8, 5)
#        Author                                              Title  \
# 0  Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1  Mark_Twain              To the Person Sitting in Darkness.txt
# 2  Mark_Twain                        Life on the Mississippi.txt
# 3  Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4  Mark_Twain                                 A Horse's Tale.txt
# 5  Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6  Mark_Twain  Following the Equator A Journey Around the Wor...
# 7  Mark_Twain  The Entire Project Gutenberg Works of Mark Twa...
#
#                                              y_train  \
# 0  THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1  TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2  Produced by David Widger. Earliest PG text edi...
# 3  KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4  A Horse’s Tale\n\n\n                          ...
# 5  1601\n\nConversation as it was by the Social F...
# 6  Produced by David Widger\n\n\n\n\n\n          ...
# 7  THE ENTIRE GUTENBERG TWAIN FILES\n\n          ...
#
#                                               y_pred  \
# 0  He made a\ntrip to Hadleyburg and found it the...
# 1  And\nthere is more of it. The People who Sit i...
# 2  A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3  They\nare saying that I have a secret, a secre...
# 4  * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5  The first edition of it was published\nin 1880...
# 6  The  Australian Desert--The  Great Barrier Ree...
# 7  1902\n     A FINE OLD WIDOW\n     A LITTLE GHO...
#
#                                               y_test
# 0  joy. He began to form a plan at once, saying t...
# 1  Game. It shows that these new players of it ar...
# 2  rd. CHAPTER XXIII. Old French Settlements.--We...
# 3  hen uttered against a king. Miscreants—they ar...
# 4  rian will correct these defects.” The cats in ...
# 5  601. The piece is a supposititious conversatio...
# 6  shing--Cecil Rhodes' Shark and his First Fortu...
# 7  SAD EXPERIENCES DAN MURPHY THE "TOURNAMENT" IN...
# Processed Roughing It.txt from Mark_Twain
# (9, 5)
#        Author                                              Title  \
# 0  Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1  Mark_Twain              To the Person Sitting in Darkness.txt
# 2  Mark_Twain                        Life on the Mississippi.txt
# 3  Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4  Mark_Twain                                 A Horse's Tale.txt
# 5  Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6  Mark_Twain  Following the Equator A Journey Around the Wor...
# 7  Mark_Twain  The Entire Project Gutenberg Works of Mark Twa...
# 8  Mark_Twain                                    Roughing It.txt
#
#                                              y_train  \
# 0  THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1  TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2  Produced by David Widger. Earliest PG text edi...
# 3  KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4  A Horse’s Tale\n\n\n                          ...
# 5  1601\n\nConversation as it was by the Social F...
# 6  Produced by David Widger\n\n\n\n\n\n          ...
# 7  THE ENTIRE GUTENBERG TWAIN FILES\n\n          ...
# 8  ROUGHING IT\n\n\nBy Mark Twain\n\n\n\n\nfronti...
#
#                                               y_pred  \
# 0  He made a\ntrip to Hadleyburg and found it the...
# 1  And\nthere is more of it. The People who Sit i...
# 2  A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3  They\nare saying that I have a secret, a secre...
# 4  * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5  The first edition of it was published\nin 1880...
# 6  The  Australian Desert--The  Great Barrier Ree...
# 7  1902\n     A FINE OLD WIDOW\n     A LITTLE GHO...
# 8  The Sutter’s Fort—The Stage Coach—The Black\nC...
#
#                                               y_test
# 0  joy. He began to form a plan at once, saying t...
# 1  Game. It shows that these new players of it ar...
# 2  rd. CHAPTER XXIII. Old French Settlements.--We...
# 3  hen uttered against a king. Miscreants—they ar...
# 4  rian will correct these defects.” The cats in ...
# 5  601. The piece is a supposititious conversatio...
# 6  shing--Cecil Rhodes' Shark and his First Fortu...
# 7  SAD EXPERIENCES DAN MURPHY THE "TOURNAMENT" IN...
# 8  APTER IX. Among the Indians—An Unfair Advantag...
# Processed A Double Barrelled Detective Story.txt from Mark_Twain
# (10, 5)
#        Author                                              Title  \
# 0  Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1  Mark_Twain              To the Person Sitting in Darkness.txt
# 2  Mark_Twain                        Life on the Mississippi.txt
# 3  Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4  Mark_Twain                                 A Horse's Tale.txt
# 5  Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6  Mark_Twain  Following the Equator A Journey Around the Wor...
# 7  Mark_Twain  The Entire Project Gutenberg Works of Mark Twa...
# 8  Mark_Twain                                    Roughing It.txt
# 9  Mark_Twain             A Double Barrelled Detective Story.txt
#
#                                              y_train  \
# 0  THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1  TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2  Produced by David Widger. Earliest PG text edi...
# 3  KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4  A Horse’s Tale\n\n\n                          ...
# 5  1601\n\nConversation as it was by the Social F...
# 6  Produced by David Widger\n\n\n\n\n\n          ...
# 7  THE ENTIRE GUTENBERG TWAIN FILES\n\n          ...
# 8  ROUGHING IT\n\n\nBy Mark Twain\n\n\n\n\nfronti...
# 9  A DOUBLE BARRELLED DETECTIVE STORY\n\nBy Mark ...
#
#                                               y_pred  \
# 0  He made a\ntrip to Hadleyburg and found it the...
# 1  And\nthere is more of it. The People who Sit i...
# 2  A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3  They\nare saying that I have a secret, a secre...
# 4  * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5  The first edition of it was published\nin 1880...
# 6  The  Australian Desert--The  Great Barrier Ree...
# 7  1902\n     A FINE OLD WIDOW\n     A LITTLE GHO...
# 8  The Sutter’s Fort—The Stage Coach—The Black\nC...
# 9  At last, after a few weeks, the wife, in the d...
#
#                                               y_test
# 0  joy. He began to form a plan at once, saying t...
# 1  Game. It shows that these new players of it ar...
# 2  rd. CHAPTER XXIII. Old French Settlements.--We...
# 3  hen uttered against a king. Miscreants—they ar...
# 4  rian will correct these defects.” The cats in ...
# 5  601. The piece is a supposititious conversatio...
# 6  shing--Cecil Rhodes' Shark and his First Fortu...
# 7  SAD EXPERIENCES DAN MURPHY THE "TOURNAMENT" IN...
# 8  APTER IX. Among the Indians—An Unfair Advantag...
# 9  . She always answered, “He shall never know by...
# Processed Christian Science.txt from Mark_Twain
# (11, 5)
#         Author                                              Title  \
# 0   Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1   Mark_Twain              To the Person Sitting in Darkness.txt
# 2   Mark_Twain                        Life on the Mississippi.txt
# 3   Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4   Mark_Twain                                 A Horse's Tale.txt
# 5   Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6   Mark_Twain  Following the Equator A Journey Around the Wor...
# 7   Mark_Twain  The Entire Project Gutenberg Works of Mark Twa...
# 8   Mark_Twain                                    Roughing It.txt
# 9   Mark_Twain             A Double Barrelled Detective Story.txt
# 10  Mark_Twain                              Christian Science.txt
#
#                                               y_train  \
# 0   THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1   TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2   Produced by David Widger. Earliest PG text edi...
# 3   KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4   A Horse’s Tale\n\n\n                          ...
# 5   1601\n\nConversation as it was by the Social F...
# 6   Produced by David Widger\n\n\n\n\n\n          ...
# 7   THE ENTIRE GUTENBERG TWAIN FILES\n\n          ...
# 8   ROUGHING IT\n\n\nBy Mark Twain\n\n\n\n\nfronti...
# 9   A DOUBLE BARRELLED DETECTIVE STORY\n\nBy Mark ...
# 10  CHRISTIAN SCIENCE\n\nby Mark Twain\n\n\n\n\nPR...
#
#                                                y_pred  \
# 0   He made a\ntrip to Hadleyburg and found it the...
# 1   And\nthere is more of it. The People who Sit i...
# 2   A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3   They\nare saying that I have a secret, a secre...
# 4   * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5   The first edition of it was published\nin 1880...
# 6   The  Australian Desert--The  Great Barrier Ree...
# 7   1902\n     A FINE OLD WIDOW\n     A LITTLE GHO...
# 8   The Sutter’s Fort—The Stage Coach—The Black\nC...
# 9   At last, after a few weeks, the wife, in the d...
# 10  I was in a very bad way, and I\ncould not imag...
#
#                                                y_test
# 0   joy. He began to form a plan at once, saying t...
# 1   Game. It shows that these new players of it ar...
# 2   rd. CHAPTER XXIII. Old French Settlements.--We...
# 3   hen uttered against a king. Miscreants—they ar...
# 4   rian will correct these defects.” The cats in ...
# 5   601. The piece is a supposititious conversatio...
# 6   shing--Cecil Rhodes' Shark and his First Fortu...
# 7   SAD EXPERIENCES DAN MURPHY THE "TOURNAMENT" IN...
# 8   APTER IX. Among the Indians—An Unfair Advantag...
# 9   . She always answered, “He shall never know by...
# 10  mistake. “Did you tell her I walked off a clif...
# Processed The Mysterious Stranger, and Other Stories.txt from Mark_Twain
# (12, 5)
#         Author                                              Title  \
# 0   Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1   Mark_Twain              To the Person Sitting in Darkness.txt
# 2   Mark_Twain                        Life on the Mississippi.txt
# 3   Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4   Mark_Twain                                 A Horse's Tale.txt
# 5   Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6   Mark_Twain  Following the Equator A Journey Around the Wor...
# 7   Mark_Twain  The Entire Project Gutenberg Works of Mark Twa...
# 8   Mark_Twain                                    Roughing It.txt
# 9   Mark_Twain             A Double Barrelled Detective Story.txt
# 10  Mark_Twain                              Christian Science.txt
# 11  Mark_Twain     The Mysterious Stranger, and Other Stories.txt
#
#                                               y_train  \
# 0   THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1   TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2   Produced by David Widger. Earliest PG text edi...
# 3   KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4   A Horse’s Tale\n\n\n                          ...
# 5   1601\n\nConversation as it was by the Social F...
# 6   Produced by David Widger\n\n\n\n\n\n          ...
# 7   THE ENTIRE GUTENBERG TWAIN FILES\n\n          ...
# 8   ROUGHING IT\n\n\nBy Mark Twain\n\n\n\n\nfronti...
# 9   A DOUBLE BARRELLED DETECTIVE STORY\n\nBy Mark ...
# 10  CHRISTIAN SCIENCE\n\nby Mark Twain\n\n\n\n\nPR...
# 11  THE MYSTERIOUS STRANGER\n\nby Mark Twain\n\n\n...
#
#                                                y_pred  \
# 0   He made a\ntrip to Hadleyburg and found it the...
# 1   And\nthere is more of it. The People who Sit i...
# 2   A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3   They\nare saying that I have a secret, a secre...
# 4   * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5   The first edition of it was published\nin 1880...
# 6   The  Australian Desert--The  Great Barrier Ree...
# 7   1902\n     A FINE OLD WIDOW\n     A LITTLE GHO...
# 8   The Sutter’s Fort—The Stage Coach—The Black\nC...
# 9   At last, after a few weeks, the wife, in the d...
# 10  I was in a very bad way, and I\ncould not imag...
# 11  We were taught to\nreverence and fear the Virg...
#
#                                                y_test
# 0   joy. He began to form a plan at once, saying t...
# 1   Game. It shows that these new players of it ar...
# 2   rd. CHAPTER XXIII. Old French Settlements.--We...
# 3   hen uttered against a king. Miscreants—they ar...
# 4   rian will correct these defects.” The cats in ...
# 5   601. The piece is a supposititious conversatio...
# 6   shing--Cecil Rhodes' Shark and his First Fortu...
# 7   SAD EXPERIENCES DAN MURPHY THE "TOURNAMENT" IN...
# 8   APTER IX. Among the Indians—An Unfair Advantag...
# 9   . She always answered, “He shall never know by...
# 10  mistake. “Did you tell her I walked off a clif...
# 11  plans. We had two priests. One of them, Father...
# Processed Extract from Captain Stormfield's Visit to Heaven.txt from Mark_Twain
# (13, 5)
#         Author                                              Title  \
# 0   Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1   Mark_Twain              To the Person Sitting in Darkness.txt
# 2   Mark_Twain                        Life on the Mississippi.txt
# 3   Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4   Mark_Twain                                 A Horse's Tale.txt
# 5   Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6   Mark_Twain  Following the Equator A Journey Around the Wor...
# 7   Mark_Twain  The Entire Project Gutenberg Works of Mark Twa...
# 8   Mark_Twain                                    Roughing It.txt
# 9   Mark_Twain             A Double Barrelled Detective Story.txt
# 10  Mark_Twain                              Christian Science.txt
# 11  Mark_Twain     The Mysterious Stranger, and Other Stories.txt
# 12  Mark_Twain  Extract from Captain Stormfield's Visit to Hea...
#
#                                               y_train  \
# 0   THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1   TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2   Produced by David Widger. Earliest PG text edi...
# 3   KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4   A Horse’s Tale\n\n\n                          ...
# 5   1601\n\nConversation as it was by the Social F...
# 6   Produced by David Widger\n\n\n\n\n\n          ...
# 7   THE ENTIRE GUTENBERG TWAIN FILES\n\n          ...
# 8   ROUGHING IT\n\n\nBy Mark Twain\n\n\n\n\nfronti...
# 9   A DOUBLE BARRELLED DETECTIVE STORY\n\nBy Mark ...
# 10  CHRISTIAN SCIENCE\n\nby Mark Twain\n\n\n\n\nPR...
# 11  THE MYSTERIOUS STRANGER\n\nby Mark Twain\n\n\n...
# 12  Transcribed by David Price, email ccx074@pglaf...
#
#                                                y_pred  \
# 0   He made a\ntrip to Hadleyburg and found it the...
# 1   And\nthere is more of it. The People who Sit i...
# 2   A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3   They\nare saying that I have a secret, a secre...
# 4   * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5   The first edition of it was published\nin 1880...
# 6   The  Australian Desert--The  Great Barrier Ree...
# 7   1902\n     A FINE OLD WIDOW\n     A LITTLE GHO...
# 8   The Sutter’s Fort—The Stage Coach—The Black\nC...
# 9   At last, after a few weeks, the wife, in the d...
# 10  I was in a very bad way, and I\ncould not imag...
# 11  We were taught to\nreverence and fear the Virg...
# 12  I came to a point where the space was all lit ...
#
#                                                y_test
# 0   joy. He began to form a plan at once, saying t...
# 1   Game. It shows that these new players of it ar...
# 2   rd. CHAPTER XXIII. Old French Settlements.--We...
# 3   hen uttered against a king. Miscreants—they ar...
# 4   rian will correct these defects.” The cats in ...
# 5   601. The piece is a supposititious conversatio...
# 6   shing--Cecil Rhodes' Shark and his First Fortu...
# 7   SAD EXPERIENCES DAN MURPHY THE "TOURNAMENT" IN...
# 8   APTER IX. Among the Indians—An Unfair Advantag...
# 9   . She always answered, “He shall never know by...
# 10  mistake. “Did you tell her I walked off a clif...
# 11  plans. We had two priests. One of them, Father...
# 12  e and tore along. By and by I closed up abreas...
# Processed The Innocents Abroad.txt from Mark_Twain
# (14, 5)
#         Author                                              Title  \
# 0   Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1   Mark_Twain              To the Person Sitting in Darkness.txt
# 2   Mark_Twain                        Life on the Mississippi.txt
# 3   Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4   Mark_Twain                                 A Horse's Tale.txt
# 5   Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6   Mark_Twain  Following the Equator A Journey Around the Wor...
# 7   Mark_Twain  The Entire Project Gutenberg Works of Mark Twa...
# 8   Mark_Twain                                    Roughing It.txt
# 9   Mark_Twain             A Double Barrelled Detective Story.txt
# 10  Mark_Twain                              Christian Science.txt
# 11  Mark_Twain     The Mysterious Stranger, and Other Stories.txt
# 12  Mark_Twain  Extract from Captain Stormfield's Visit to Hea...
# 13  Mark_Twain                           The Innocents Abroad.txt
#
#                                               y_train  \
# 0   THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1   TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2   Produced by David Widger. Earliest PG text edi...
# 3   KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4   A Horse’s Tale\n\n\n                          ...
# 5   1601\n\nConversation as it was by the Social F...
# 6   Produced by David Widger\n\n\n\n\n\n          ...
# 7   THE ENTIRE GUTENBERG TWAIN FILES\n\n          ...
# 8   ROUGHING IT\n\n\nBy Mark Twain\n\n\n\n\nfronti...
# 9   A DOUBLE BARRELLED DETECTIVE STORY\n\nBy Mark ...
# 10  CHRISTIAN SCIENCE\n\nby Mark Twain\n\n\n\n\nPR...
# 11  THE MYSTERIOUS STRANGER\n\nby Mark Twain\n\n\n...
# 12  Transcribed by David Price, email ccx074@pglaf...
# 13  INNOCENTS ABROAD\n\nby Mark Twain\n\n\n[From a...
#
#                                                y_pred  \
# 0   He made a\ntrip to Hadleyburg and found it the...
# 1   And\nthere is more of it. The People who Sit i...
# 2   A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3   They\nare saying that I have a secret, a secre...
# 4   * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5   The first edition of it was published\nin 1880...
# 6   The  Australian Desert--The  Great Barrier Ree...
# 7   1902\n     A FINE OLD WIDOW\n     A LITTLE GHO...
# 8   The Sutter’s Fort—The Stage Coach—The Black\nC...
# 9   At last, after a few weeks, the wife, in the d...
# 10  I was in a very bad way, and I\ncould not imag...
# 11  We were taught to\nreverence and fear the Virg...
# 12  I came to a point where the space was all lit ...
# 13  The Road to the Alps--The Swiss Alps--A Pictor...
#
#                                                y_test
# 0   joy. He began to form a plan at once, saying t...
# 1   Game. It shows that these new players of it ar...
# 2   rd. CHAPTER XXIII. Old French Settlements.--We...
# 3   hen uttered against a king. Miscreants—they ar...
# 4   rian will correct these defects.” The cats in ...
# 5   601. The piece is a supposititious conversatio...
# 6   shing--Cecil Rhodes' Shark and his First Fortu...
# 7   SAD EXPERIENCES DAN MURPHY THE "TOURNAMENT" IN...
# 8   APTER IX. Among the Indians—An Unfair Advantag...
# 9   . She always answered, “He shall never know by...
# 10  mistake. “Did you tell her I walked off a clif...
# 11  plans. We had two priests. One of them, Father...
# 12  e and tore along. By and by I closed up abreas...
# 13  War--The American Forces Victorious--” Home Ag...
# Processed The Man That Corrupted Hadleyburg (2).txt from Mark_Twain
# (15, 5)
#         Author                                              Title  \
# 0   Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1   Mark_Twain              To the Person Sitting in Darkness.txt
# 2   Mark_Twain                        Life on the Mississippi.txt
# 3   Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4   Mark_Twain                                 A Horse's Tale.txt
# 5   Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6   Mark_Twain  Following the Equator A Journey Around the Wor...
# 7   Mark_Twain  The Entire Project Gutenberg Works of Mark Twa...
# 8   Mark_Twain                                    Roughing It.txt
# 9   Mark_Twain             A Double Barrelled Detective Story.txt
# 10  Mark_Twain                              Christian Science.txt
# 11  Mark_Twain     The Mysterious Stranger, and Other Stories.txt
# 12  Mark_Twain  Extract from Captain Stormfield's Visit to Hea...
# 13  Mark_Twain                           The Innocents Abroad.txt
# 14  Mark_Twain          The Man That Corrupted Hadleyburg (2).txt
#
#                                               y_train  \
# 0   THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1   TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2   Produced by David Widger. Earliest PG text edi...
# 3   KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4   A Horse’s Tale\n\n\n                          ...
# 5   1601\n\nConversation as it was by the Social F...
# 6   Produced by David Widger\n\n\n\n\n\n          ...
# 7   THE ENTIRE GUTENBERG TWAIN FILES\n\n          ...
# 8   ROUGHING IT\n\n\nBy Mark Twain\n\n\n\n\nfronti...
# 9   A DOUBLE BARRELLED DETECTIVE STORY\n\nBy Mark ...
# 10  CHRISTIAN SCIENCE\n\nby Mark Twain\n\n\n\n\nPR...
# 11  THE MYSTERIOUS STRANGER\n\nby Mark Twain\n\n\n...
# 12  Transcribed by David Price, email ccx074@pglaf...
# 13  INNOCENTS ABROAD\n\nby Mark Twain\n\n\n[From a...
# 14  THE MAN THAT CORRUPTED HADLEYBURG\n\n\nI. It w...
#
#                                                y_pred  \
# 0   He made a\ntrip to Hadleyburg and found it the...
# 1   And\nthere is more of it. The People who Sit i...
# 2   A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3   They\nare saying that I have a secret, a secre...
# 4   * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5   The first edition of it was published\nin 1880...
# 6   The  Australian Desert--The  Great Barrier Ree...
# 7   1902\n     A FINE OLD WIDOW\n     A LITTLE GHO...
# 8   The Sutter’s Fort—The Stage Coach—The Black\nC...
# 9   At last, after a few weeks, the wife, in the d...
# 10  I was in a very bad way, and I\ncould not imag...
# 11  We were taught to\nreverence and fear the Virg...
# 12  I came to a point where the space was all lit ...
# 13  The Road to the Alps--The Swiss Alps--A Pictor...
# 14  I have\nbrought a sack of money, and I am goin...
#
#                                                y_test
# 0   joy. He began to form a plan at once, saying t...
# 1   Game. It shows that these new players of it ar...
# 2   rd. CHAPTER XXIII. Old French Settlements.--We...
# 3   hen uttered against a king. Miscreants—they ar...
# 4   rian will correct these defects.” The cats in ...
# 5   601. The piece is a supposititious conversatio...
# 6   shing--Cecil Rhodes' Shark and his First Fortu...
# 7   SAD EXPERIENCES DAN MURPHY THE "TOURNAMENT" IN...
# 8   APTER IX. Among the Indians—An Unfair Advantag...
# 9   . She always answered, “He shall never know by...
# 10  mistake. “Did you tell her I walked off a clif...
# 11  plans. We had two priests. One of them, Father...
# 12  e and tore along. By and by I closed up abreas...
# 13  War--The American Forces Victorious--” Home Ag...
# 14  e. Can I see your husband a moment, madam?” No...
# Processed Some Rambling Notes of an Idle Excursion.txt from Mark_Twain
# (16, 5)
#         Author                                              Title  \
# 0   Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1   Mark_Twain              To the Person Sitting in Darkness.txt
# 2   Mark_Twain                        Life on the Mississippi.txt
# 3   Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4   Mark_Twain                                 A Horse's Tale.txt
# 5   Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6   Mark_Twain  Following the Equator A Journey Around the Wor...
# 7   Mark_Twain  The Entire Project Gutenberg Works of Mark Twa...
# 8   Mark_Twain                                    Roughing It.txt
# 9   Mark_Twain             A Double Barrelled Detective Story.txt
# 10  Mark_Twain                              Christian Science.txt
# 11  Mark_Twain     The Mysterious Stranger, and Other Stories.txt
# 12  Mark_Twain  Extract from Captain Stormfield's Visit to Hea...
# 13  Mark_Twain                           The Innocents Abroad.txt
# 14  Mark_Twain          The Man That Corrupted Hadleyburg (2).txt
# 15  Mark_Twain       Some Rambling Notes of an Idle Excursion.txt
#
#                                               y_train  \
# 0   THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1   TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2   Produced by David Widger. Earliest PG text edi...
# 3   KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4   A Horse’s Tale\n\n\n                          ...
# 5   1601\n\nConversation as it was by the Social F...
# 6   Produced by David Widger\n\n\n\n\n\n          ...
# 7   THE ENTIRE GUTENBERG TWAIN FILES\n\n          ...
# 8   ROUGHING IT\n\n\nBy Mark Twain\n\n\n\n\nfronti...
# 9   A DOUBLE BARRELLED DETECTIVE STORY\n\nBy Mark ...
# 10  CHRISTIAN SCIENCE\n\nby Mark Twain\n\n\n\n\nPR...
# 11  THE MYSTERIOUS STRANGER\n\nby Mark Twain\n\n\n...
# 12  Transcribed by David Price, email ccx074@pglaf...
# 13  INNOCENTS ABROAD\n\nby Mark Twain\n\n\n[From a...
# 14  THE MAN THAT CORRUPTED HADLEYBURG\n\n\nI. It w...
# 15  SOME RAMBLING NOTES OF AN IDLE EXCURSION\n\nby...
#
#                                                y_pred  \
# 0   He made a\ntrip to Hadleyburg and found it the...
# 1   And\nthere is more of it. The People who Sit i...
# 2   A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3   They\nare saying that I have a secret, a secre...
# 4   * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5   The first edition of it was published\nin 1880...
# 6   The  Australian Desert--The  Great Barrier Ree...
# 7   1902\n     A FINE OLD WIDOW\n     A LITTLE GHO...
# 8   The Sutter’s Fort—The Stage Coach—The Black\nC...
# 9   At last, after a few weeks, the wife, in the d...
# 10  I was in a very bad way, and I\ncould not imag...
# 11  We were taught to\nreverence and fear the Virg...
# 12  I came to a point where the space was all lit ...
# 13  The Road to the Alps--The Swiss Alps--A Pictor...
# 14  I have\nbrought a sack of money, and I am goin...
# 15  It's but a dollar, and it's\na thing that can ...
#
#                                                y_test
# 0   joy. He began to form a plan at once, saying t...
# 1   Game. It shows that these new players of it ar...
# 2   rd. CHAPTER XXIII. Old French Settlements.--We...
# 3   hen uttered against a king. Miscreants—they ar...
# 4   rian will correct these defects.” The cats in ...
# 5   601. The piece is a supposititious conversatio...
# 6   shing--Cecil Rhodes' Shark and his First Fortu...
# 7   SAD EXPERIENCES DAN MURPHY THE "TOURNAMENT" IN...
# 8   APTER IX. Among the Indians—An Unfair Advantag...
# 9   . She always answered, “He shall never know by...
# 10  mistake. “Did you tell her I walked off a clif...
# 11  plans. We had two priests. One of them, Father...
# 12  e and tore along. By and by I closed up abreas...
# 13  War--The American Forces Victorious--” Home Ag...
# 14  e. Can I see your husband a moment, madam?” No...
# 15  ? Life's on'y a pilgrimage, says I; we ain't h...
# Processed Personal Recollections of Joan of Arc — Volume 2.txt from Mark_Twain
# (17, 5)
#         Author                                              Title  \
# 0   Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1   Mark_Twain              To the Person Sitting in Darkness.txt
# 2   Mark_Twain                        Life on the Mississippi.txt
# 3   Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4   Mark_Twain                                 A Horse's Tale.txt
# 5   Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6   Mark_Twain  Following the Equator A Journey Around the Wor...
# 7   Mark_Twain  The Entire Project Gutenberg Works of Mark Twa...
# 8   Mark_Twain                                    Roughing It.txt
# 9   Mark_Twain             A Double Barrelled Detective Story.txt
# 10  Mark_Twain                              Christian Science.txt
# 11  Mark_Twain     The Mysterious Stranger, and Other Stories.txt
# 12  Mark_Twain  Extract from Captain Stormfield's Visit to Hea...
# 13  Mark_Twain                           The Innocents Abroad.txt
# 14  Mark_Twain          The Man That Corrupted Hadleyburg (2).txt
# 15  Mark_Twain       Some Rambling Notes of an Idle Excursion.txt
# 16  Mark_Twain  Personal Recollections of Joan of Arc — Volume...
#
#                                               y_train  \
# 0   THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1   TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2   Produced by David Widger. Earliest PG text edi...
# 3   KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4   A Horse’s Tale\n\n\n                          ...
# 5   1601\n\nConversation as it was by the Social F...
# 6   Produced by David Widger\n\n\n\n\n\n          ...
# 7   THE ENTIRE GUTENBERG TWAIN FILES\n\n          ...
# 8   ROUGHING IT\n\n\nBy Mark Twain\n\n\n\n\nfronti...
# 9   A DOUBLE BARRELLED DETECTIVE STORY\n\nBy Mark ...
# 10  CHRISTIAN SCIENCE\n\nby Mark Twain\n\n\n\n\nPR...
# 11  THE MYSTERIOUS STRANGER\n\nby Mark Twain\n\n\n...
# 12  Transcribed by David Price, email ccx074@pglaf...
# 13  INNOCENTS ABROAD\n\nby Mark Twain\n\n\n[From a...
# 14  THE MAN THAT CORRUPTED HADLEYBURG\n\n\nI. It w...
# 15  SOME RAMBLING NOTES OF AN IDLE EXCURSION\n\nby...
# 16  PERSONAL RECOLLECTIONS OF\n\nJOAN OF ARC\n\n V...
#
#                                                y_pred  \
# 0   He made a\ntrip to Hadleyburg and found it the...
# 1   And\nthere is more of it. The People who Sit i...
# 2   A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3   They\nare saying that I have a secret, a secre...
# 4   * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5   The first edition of it was published\nin 1880...
# 6   The  Australian Desert--The  Great Barrier Ree...
# 7   1902\n     A FINE OLD WIDOW\n     A LITTLE GHO...
# 8   The Sutter’s Fort—The Stage Coach—The Black\nC...
# 9   At last, after a few weeks, the wife, in the d...
# 10  I was in a very bad way, and I\ncould not imag...
# 11  We were taught to\nreverence and fear the Virg...
# 12  I came to a point where the space was all lit ...
# 13  The Road to the Alps--The Swiss Alps--A Pictor...
# 14  I have\nbrought a sack of money, and I am goin...
# 15  It's but a dollar, and it's\na thing that can ...
# 16  I think you have been very foolish.”\n\nJoan s...
#
#                                                y_test
# 0   joy. He began to form a plan at once, saying t...
# 1   Game. It shows that these new players of it ar...
# 2   rd. CHAPTER XXIII. Old French Settlements.--We...
# 3   hen uttered against a king. Miscreants—they ar...
# 4   rian will correct these defects.” The cats in ...
# 5   601. The piece is a supposititious conversatio...
# 6   shing--Cecil Rhodes' Shark and his First Fortu...
# 7   SAD EXPERIENCES DAN MURPHY THE "TOURNAMENT" IN...
# 8   APTER IX. Among the Indians—An Unfair Advantag...
# 9   . She always answered, “He shall never know by...
# 10  mistake. “Did you tell her I walked off a clif...
# 11  plans. We had two priests. One of them, Father...
# 12  e and tore along. By and by I closed up abreas...
# 13  War--The American Forces Victorious--” Home Ag...
# 14  e. Can I see your husband a moment, madam?” No...
# 15  ? Life's on'y a pilgrimage, says I; we ain't h...
# 16  And you led an assault again. Joan, it is temp...
# Processed A Tramp Abroad.txt from Mark_Twain
# (18, 5)
#         Author                                              Title  \
# 0   Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1   Mark_Twain              To the Person Sitting in Darkness.txt
# 2   Mark_Twain                        Life on the Mississippi.txt
# 3   Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4   Mark_Twain                                 A Horse's Tale.txt
# 5   Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6   Mark_Twain  Following the Equator A Journey Around the Wor...
# 7   Mark_Twain  The Entire Project Gutenberg Works of Mark Twa...
# 8   Mark_Twain                                    Roughing It.txt
# 9   Mark_Twain             A Double Barrelled Detective Story.txt
# 10  Mark_Twain                              Christian Science.txt
# 11  Mark_Twain     The Mysterious Stranger, and Other Stories.txt
# 12  Mark_Twain  Extract from Captain Stormfield's Visit to Hea...
# 13  Mark_Twain                           The Innocents Abroad.txt
# 14  Mark_Twain          The Man That Corrupted Hadleyburg (2).txt
# 15  Mark_Twain       Some Rambling Notes of an Idle Excursion.txt
# 16  Mark_Twain  Personal Recollections of Joan of Arc — Volume...
# 17  Mark_Twain                                 A Tramp Abroad.txt
#
#                                               y_train  \
# 0   THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1   TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2   Produced by David Widger. Earliest PG text edi...
# 3   KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4   A Horse’s Tale\n\n\n                          ...
# 5   1601\n\nConversation as it was by the Social F...
# 6   Produced by David Widger\n\n\n\n\n\n          ...
# 7   THE ENTIRE GUTENBERG TWAIN FILES\n\n          ...
# 8   ROUGHING IT\n\n\nBy Mark Twain\n\n\n\n\nfronti...
# 9   A DOUBLE BARRELLED DETECTIVE STORY\n\nBy Mark ...
# 10  CHRISTIAN SCIENCE\n\nby Mark Twain\n\n\n\n\nPR...
# 11  THE MYSTERIOUS STRANGER\n\nby Mark Twain\n\n\n...
# 12  Transcribed by David Price, email ccx074@pglaf...
# 13  INNOCENTS ABROAD\n\nby Mark Twain\n\n\n[From a...
# 14  THE MAN THAT CORRUPTED HADLEYBURG\n\n\nI. It w...
# 15  SOME RAMBLING NOTES OF AN IDLE EXCURSION\n\nby...
# 16  PERSONAL RECOLLECTIONS OF\n\nJOAN OF ARC\n\n V...
# 17  A TRAMP ABROAD, Part 1\n\nBy Mark Twain\n\n(Sa...
#
#                                                y_pred  \
# 0   He made a\ntrip to Hadleyburg and found it the...
# 1   And\nthere is more of it. The People who Sit i...
# 2   A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3   They\nare saying that I have a secret, a secre...
# 4   * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5   The first edition of it was published\nin 1880...
# 6   The  Australian Desert--The  Great Barrier Ree...
# 7   1902\n     A FINE OLD WIDOW\n     A LITTLE GHO...
# 8   The Sutter’s Fort—The Stage Coach—The Black\nC...
# 9   At last, after a few weeks, the wife, in the d...
# 10  I was in a very bad way, and I\ncould not imag...
# 11  We were taught to\nreverence and fear the Virg...
# 12  I came to a point where the space was all lit ...
# 13  The Road to the Alps--The Swiss Alps--A Pictor...
# 14  I have\nbrought a sack of money, and I am goin...
# 15  It's but a dollar, and it's\na thing that can ...
# 16  I think you have been very foolish.”\n\nJoan s...
# 17  Harris, I suppose, thought that I was not very...
#
#                                                y_test
# 0   joy. He began to form a plan at once, saying t...
# 1   Game. It shows that these new players of it ar...
# 2   rd. CHAPTER XXIII. Old French Settlements.--We...
# 3   hen uttered against a king. Miscreants—they ar...
# 4   rian will correct these defects.” The cats in ...
# 5   601. The piece is a supposititious conversatio...
# 6   shing--Cecil Rhodes' Shark and his First Fortu...
# 7   SAD EXPERIENCES DAN MURPHY THE "TOURNAMENT" IN...
# 8   APTER IX. Among the Indians—An Unfair Advantag...
# 9   . She always answered, “He shall never know by...
# 10  mistake. “Did you tell her I walked off a clif...
# 11  plans. We had two priests. One of them, Father...
# 12  e and tore along. By and by I closed up abreas...
# 13  War--The American Forces Victorious--” Home Ag...
# 14  e. Can I see your husband a moment, madam?” No...
# 15  ? Life's on'y a pilgrimage, says I; we ain't h...
# 16  And you led an assault again. Joan, it is temp...
# 17  purpose to study art while in Europe. Mr. Harr...
# Processed The Facts Concerning the Recent Carnival of Crime in Connecticut.txt from Mark_Twain
# (19, 5)
#         Author                                              Title  \
# 0   Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1   Mark_Twain              To the Person Sitting in Darkness.txt
# 2   Mark_Twain                        Life on the Mississippi.txt
# 3   Mark_Twain                       KING LEOPOLD’S SOLILOQUY.txt
# 4   Mark_Twain                                 A Horse's Tale.txt
# 5   Mark_Twain  1601 Conversation as it was by the Social Fire...
# 6   Mark_Twain  Following the Equator A Journey Around the Wor...
# 7   Mark_Twain  The Entire Project Gutenberg Works of Mark Twa...
# 8   Mark_Twain                                    Roughing It.txt
# 9   Mark_Twain             A Double Barrelled Detective Story.txt
# 10  Mark_Twain                              Christian Science.txt
# 11  Mark_Twain     The Mysterious Stranger, and Other Stories.txt
# 12  Mark_Twain  Extract from Captain Stormfield's Visit to Hea...
# 13  Mark_Twain                           The Innocents Abroad.txt
# 14  Mark_Twain          The Man That Corrupted Hadleyburg (2).txt
# 15  Mark_Twain       Some Rambling Notes of an Idle Excursion.txt
# 16  Mark_Twain  Personal Recollections of Joan of Arc — Volume...
# 17  Mark_Twain                                 A Tramp Abroad.txt
# 18  Mark_Twain  The Facts Concerning the Recent Carnival of Cr...
#
#                                               y_train  \
# 0   THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1   TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2   Produced by David Widger. Earliest PG text edi...
# 3   KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4   A Horse’s Tale\n\n\n                          ...
# 5   1601\n\nConversation as it was by the Social F...
# 6   Produced by David Widger\n\n\n\n\n\n          ...
# ...
# 2    A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3    They\nare saying that I have a secret, a secre...
# 4    * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# ..                                                 ...
# 368  The bill is so regressive that even the Tax Po...
# 369  The private sector is not the same as the publ...
# 370  So, it’s not just the wealthy who are ignorant...
# 371  But if you look at the data, the U.S. economy ...
# 372  Also, the fact that the US is still on the edg...
#
#                                                 y_test
# 0    joy. He began to form a plan at once, saying t...
# 1    Game. It shows that these new players of it ar...
# 2    rd. CHAPTER XXIII. Old French Settlements.--We...
# 3    hen uttered against a king. Miscreants—they ar...
# 4    rian will correct these defects.” The cats in ...
# ..                                                 ...
# 368  And after some adjustments to make the bill ev...
# 369  Basic research is a public good: it generates ...
# 370  Does anyone remember Dimon proclaiming in 2014...
# 371  Scott Bessent, the Treasury secretary, keeps c...
# 372
#
# [373 rows x 5 columns]
# Processed A Real Liberation Day.txt from Paul Krugman
# (374, 5)
#            Author                                          Title  \
# 0      Mark_Twain          THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1      Mark_Twain          To the Person Sitting in Darkness.txt
# 2      Mark_Twain                    Life on the Mississippi.txt
# 3      Mark_Twain                   KING LEOPOLD’S SOLILOQUY.txt
# 4      Mark_Twain                             A Horse's Tale.txt
# ..            ...                                            ...
# 369  Paul Krugman                      MAGA’s War on Science.txt
# 370  Paul Krugman  Political Styles of the Rich and Clueless.txt
# 371  Paul Krugman   Will Trump Pretend to Fix What He Broke_.txt
# 372  Paul Krugman                 The Noise Before the Storm.txt
# 373  Paul Krugman                      A Real Liberation Day.txt
#
#                                                y_train  \
# 0    THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1    TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2    Produced by David Widger. Earliest PG text edi...
# 3    KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4    A Horse’s Tale\n\n\n                          ...
# ..                                                 ...
# 369  Hey, no more of that! A late, brief post today...
# 370  As we wait to see what fresh hell awaits us th...
# 371  The Trump administration is planning to announ...
# 372  I’m traveling and won’t be able to get a prope...
# 373  Finished today’s travel and arrived to find th...
#
#                                                 y_pred  \
# 0    He made a\ntrip to Hadleyburg and found it the...
# 1    And\nthere is more of it. The People who Sit i...
# 2    A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3    They\nare saying that I have a secret, a secre...
# 4    * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# ..                                                 ...
# 369  The private sector is not the same as the publ...
# 370  So, it’s not just the wealthy who are ignorant...
# 371  But if you look at the data, the U.S. economy ...
# 372  Also, the fact that the US is still on the edg...
# 373  The problem is that in our country, the opposi...
#
#                                                 y_test
# 0    joy. He began to form a plan at once, saying t...
# 1    Game. It shows that these new players of it ar...
# 2    rd. CHAPTER XXIII. Old French Settlements.--We...
# 3    hen uttered against a king. Miscreants—they ar...
# 4    rian will correct these defects.” The cats in ...
# ..                                                 ...
# 369  Basic research is a public good: it generates ...
# 370  Does anyone remember Dimon proclaiming in 2014...
# 371  Scott Bessent, the Treasury secretary, keeps c...
# 372
# 373
#
# [374 rows x 5 columns]
# Processed Making Sweatshops Great Again.txt from Paul Krugman
# (375, 5)
#            Author                                          Title  \
# 0      Mark_Twain          THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1      Mark_Twain          To the Person Sitting in Darkness.txt
# 2      Mark_Twain                    Life on the Mississippi.txt
# 3      Mark_Twain                   KING LEOPOLD’S SOLILOQUY.txt
# 4      Mark_Twain                             A Horse's Tale.txt
# ..            ...                                            ...
# 370  Paul Krugman  Political Styles of the Rich and Clueless.txt
# 371  Paul Krugman   Will Trump Pretend to Fix What He Broke_.txt
# 372  Paul Krugman                 The Noise Before the Storm.txt
# 373  Paul Krugman                      A Real Liberation Day.txt
# 374  Paul Krugman              Making Sweatshops Great Again.txt
#
#                                                y_train  \
# 0    THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1    TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2    Produced by David Widger. Earliest PG text edi...
# 3    KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4    A Horse’s Tale\n\n\n                          ...
# ..                                                 ...
# 370  As we wait to see what fresh hell awaits us th...
# 371  The Trump administration is planning to announ...
# 372  I’m traveling and won’t be able to get a prope...
# 373  Finished today’s travel and arrived to find th...
# 374  On Manhattan’s 7th Avenue, near the corner of ...
#
#                                                 y_pred  \
# 0    He made a\ntrip to Hadleyburg and found it the...
# 1    And\nthere is more of it. The People who Sit i...
# 2    A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3    They\nare saying that I have a secret, a secre...
# 4    * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# ..                                                 ...
# 370  So, it’s not just the wealthy who are ignorant...
# 371  But if you look at the data, the U.S. economy ...
# 372  Also, the fact that the US is still on the edg...
# 373  The problem is that in our country, the opposi...
# 374  For instance, if you have a company that’s wor...
#
#                                                 y_test
# 0    joy. He began to form a plan at once, saying t...
# 1    Game. It shows that these new players of it ar...
# 2    rd. CHAPTER XXIII. Old French Settlements.--We...
# 3    hen uttered against a king. Miscreants—they ar...
# 4    rian will correct these defects.” The cats in ...
# ..                                                 ...
# 370  Does anyone remember Dimon proclaiming in 2014...
# 371  Scott Bessent, the Treasury secretary, keeps c...
# 372
# 373
# 374  Silicon Valley is more than the sum of the ind...
#
# [375 rows x 5 columns]
# Processed Why Trump Will Lose His Trade War.txt from Paul Krugman
# (376, 5)
#            Author                                         Title  \
# 0      Mark_Twain         THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1      Mark_Twain         To the Person Sitting in Darkness.txt
# 2      Mark_Twain                   Life on the Mississippi.txt
# 3      Mark_Twain                  KING LEOPOLD’S SOLILOQUY.txt
# 4      Mark_Twain                            A Horse's Tale.txt
# ..            ...                                           ...
# 371  Paul Krugman  Will Trump Pretend to Fix What He Broke_.txt
# 372  Paul Krugman                The Noise Before the Storm.txt
# 373  Paul Krugman                     A Real Liberation Day.txt
# 374  Paul Krugman             Making Sweatshops Great Again.txt
# 375  Paul Krugman         Why Trump Will Lose His Trade War.txt
#
#                                                y_train  \
# 0    THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1    TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2    Produced by David Widger. Earliest PG text edi...
# 3    KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4    A Horse’s Tale\n\n\n                          ...
# ..                                                 ...
# 371  The Trump administration is planning to announ...
# 372  I’m traveling and won’t be able to get a prope...
# 373  Finished today’s travel and arrived to find th...
# 374  On Manhattan’s 7th Avenue, near the corner of ...
# 375  Scenes from the trade war:\nIn response to Don...
#
#                                                 y_pred  \
# 0    He made a\ntrip to Hadleyburg and found it the...
# 1    And\nthere is more of it. The People who Sit i...
# 2    A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3    They\nare saying that I have a secret, a secre...
# 4    * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# ..                                                 ...
# 371  But if you look at the data, the U.S. economy ...
# 372  Also, the fact that the US is still on the edg...
# 373  The problem is that in our country, the opposi...
# 374  For instance, if you have a company that’s wor...
# 375  Trade Deficit Falls to 2.6% of GDP, a 10-Year ...
#
#                                                 y_test
# 0    joy. He began to form a plan at once, saying t...
# 1    Game. It shows that these new players of it ar...
# 2    rd. CHAPTER XXIII. Old French Settlements.--We...
# 3    hen uttered against a king. Miscreants—they ar...
# 4    rian will correct these defects.” The cats in ...
# ..                                                 ...
# 371  Scott Bessent, the Treasury secretary, keeps c...
# 372
# 373
# 374  Silicon Valley is more than the sum of the ind...
# 375  Plans to Use Trade Negotiations to Isolate Chi...
#
# [376 rows x 5 columns]
# Processed Trump’s Cultural Revolution.txt from Paul Krugman
# (377, 5)
#            Author                                  Title  \
# 0      Mark_Twain  THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1      Mark_Twain  To the Person Sitting in Darkness.txt
# 2      Mark_Twain            Life on the Mississippi.txt
# 3      Mark_Twain           KING LEOPOLD’S SOLILOQUY.txt
# 4      Mark_Twain                     A Horse's Tale.txt
# ..            ...                                    ...
# 372  Paul Krugman         The Noise Before the Storm.txt
# 373  Paul Krugman              A Real Liberation Day.txt
# 374  Paul Krugman      Making Sweatshops Great Again.txt
# 375  Paul Krugman  Why Trump Will Lose His Trade War.txt
# 376  Paul Krugman        Trump’s Cultural Revolution.txt
#
#                                                y_train  \
# 0    THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1    TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2    Produced by David Widger. Earliest PG text edi...
# 3    KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4    A Horse’s Tale\n\n\n                          ...
# ..                                                 ...
# 372  I’m traveling and won’t be able to get a prope...
# 373  Finished today’s travel and arrived to find th...
# 374  On Manhattan’s 7th Avenue, near the corner of ...
# 375  Scenes from the trade war:\nIn response to Don...
# 376  I’m in Lisbon, speaking at a conference the Ba...
#
#                                                 y_pred  \
# 0    He made a\ntrip to Hadleyburg and found it the...
# 1    And\nthere is more of it. The People who Sit i...
# 2    A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3    They\nare saying that I have a secret, a secre...
# 4    * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# ..                                                 ...
# 372  Also, the fact that the US is still on the edg...
# 373  The problem is that in our country, the opposi...
# 374  For instance, if you have a company that’s wor...
# 375  Trade Deficit Falls to 2.6% of GDP, a 10-Year ...
# 376  In the same way, the Trumpists are not worried...
#
#                                                 y_test
# 0    joy. He began to form a plan at once, saying t...
# 1    Game. It shows that these new players of it ar...
# 2    rd. CHAPTER XXIII. Old French Settlements.--We...
# 3    hen uttered against a king. Miscreants—they ar...
# 4    rian will correct these defects.” The cats in ...
# ..                                                 ...
# 372
# 373
# 374  Silicon Valley is more than the sum of the ind...
# 375  Plans to Use Trade Negotiations to Isolate Chi...
# 376  The Trumpists are surely the same. Their rampa...
#
# [377 rows x 5 columns]
# Processed What the Musk is Happening_.txt from Paul Krugman
# (378, 5)
#            Author                                  Title  \
# 0      Mark_Twain  THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1      Mark_Twain  To the Person Sitting in Darkness.txt
# 2      Mark_Twain            Life on the Mississippi.txt
# 3      Mark_Twain           KING LEOPOLD’S SOLILOQUY.txt
# 4      Mark_Twain                     A Horse's Tale.txt
# ..            ...                                    ...
# 373  Paul Krugman              A Real Liberation Day.txt
# 374  Paul Krugman      Making Sweatshops Great Again.txt
# 375  Paul Krugman  Why Trump Will Lose His Trade War.txt
# 376  Paul Krugman        Trump’s Cultural Revolution.txt
# 377  Paul Krugman        What the Musk is Happening_.txt
#
#                                                y_train  \
# 0    THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1    TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2    Produced by David Widger. Earliest PG text edi...
# 3    KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4    A Horse’s Tale\n\n\n                          ...
# ..                                                 ...
# 373  Finished today’s travel and arrived to find th...
# 374  On Manhattan’s 7th Avenue, near the corner of ...
# 375  Scenes from the trade war:\nIn response to Don...
# 376  I’m in Lisbon, speaking at a conference the Ba...
# 377  When writing posts for this newsletter, I like...
#
#                                                 y_pred  \
# 0    He made a\ntrip to Hadleyburg and found it the...
# 1    And\nthere is more of it. The People who Sit i...
# 2    A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3    They\nare saying that I have a secret, a secre...
# 4    * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# ..                                                 ...
# 373  The problem is that in our country, the opposi...
# 374  For instance, if you have a company that’s wor...
# 375  Trade Deficit Falls to 2.6% of GDP, a 10-Year ...
# 376  In the same way, the Trumpists are not worried...
# 377  He is a private citizen, a billionaire, a self...
#
#                                                 y_test
# 0    joy. He began to form a plan at once, saying t...
# 1    Game. It shows that these new players of it ar...
# 2    rd. CHAPTER XXIII. Old French Settlements.--We...
# 3    hen uttered against a king. Miscreants—they ar...
# 4    rian will correct these defects.” The cats in ...
# ..                                                 ...
# 373
# 374  Silicon Valley is more than the sum of the ind...
# 375  Plans to Use Trade Negotiations to Isolate Chi...
# 376  The Trumpists are surely the same. Their rampa...
# 377  But Donald Trump has confirmed the move, which...
#
# [378 rows x 5 columns]

# %%
import os
import re

nlp_results = pd.DataFrame(columns=['Author', 'Title', 'y_train', 'y_pred', 'y_test'])

def remove_prefix(original, full):
    if full.startswith(original):
        return full[len(original):].lstrip()  # Remove leading spaces/newlines
    else:
        raise ValueError("The first text is not a prefix of the second.")

def split_text_by_sentences(text, word_limit):
    # Split text into sentences
    sentences = re.split(r'(?<=[.!?])\s+', text)
    train_text = ''
    word_count = 0

    for sentence in sentences:
        sentence_words = sentence.split()
        if word_count + len(sentence_words) > word_limit:
            break
        train_text += sentence + ' '
        word_count += len(sentence_words)

    # Now get the next 500 words after the train_text
    remaining_text = text[len(train_text):].strip()
    next_words = ' '.join(remaining_text.split()[:500])

    return train_text.strip(), next_words.strip()
base_path = "./"
authors = ["Robin Hanson"]

for author in authors:
    folder_path = os.path.join(base_path, author)
    for filename in os.listdir(folder_path):
        if filename.endswith('.txt'):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, 'r', encoding='utf-16') as f:
                text = f.read()
                train_text, test_text = split_text_by_sentences(text, 500)
                # Do whatever you want with train_text and test_text
                print(f'Processed {filename} from {author}')
                pred = generator(
                        train_text,
                        # generation control
                        max_new_tokens=400,      # ← exactly the number you asked for
                        temperature=0.8,         # creativity (0–2); lower is safer
                        top_p=0.9,               # nucleus sampling
                        do_sample=True,          # sampling instead of greedy
                        eos_token_id=tokenizer.eos_token_id,   # stop at end-of-text if it appears
                    )
                y_pred = pred[0]["generated_text"]
                result = remove_prefix(train_text, y_pred)
                new_row = pd.DataFrame([{'Author': author, 'Title': filename, 'y_pred': result, 'y_train': train_text, 'y_test': test_text}])
                nlp_results = pd.concat([nlp_results, new_row], ignore_index=True)
    
                print(nlp_results.shape)
                print(nlp_results)
# Out:
# Processed Elite-Only Financial Markets.txt from Robin Hanson
# (1, 5)
#          Author                             Title  \
# 0  Robin Hanson  Elite-Only Financial Markets.txt
#
#                                              y_train  \
# 0  Prediction markets are financial markets, but ...
#
#                                               y_pred  \
# 0  But the way they are structured, they have no ...
#
#                                               y_test
# 0  More accurate stock prices better achieve this...
# Processed Thinkers Must Be Heretics.txt from Robin Hanson
# (2, 5)
#          Author                             Title  \
# 0  Robin Hanson  Elite-Only Financial Markets.txt
# 1  Robin Hanson     Thinkers Must Be Heretics.txt
#
#                                              y_train  \
# 0  Prediction markets are financial markets, but ...
# 1  When we form opinions on topics, the depth of ...
#
#                                               y_pred  \
# 0  But the way they are structured, they have no ...
# 1  So, in our thinking, we often do not do the mo...
#
#                                               y_test
# 0  More accurate stock prices better achieve this...
# 1  Thinking-for-yourself, however, has a big prob...
# Processed ‘Long Reflection’ Is Crazy Bad Idea.txt from Robin Hanson
# (3, 5)
#          Author                                    Title  \
# 0  Robin Hanson         Elite-Only Financial Markets.txt
# 1  Robin Hanson            Thinkers Must Be Heretics.txt
# 2  Robin Hanson  ‘Long Reflection’ Is Crazy Bad Idea.txt
#
#                                              y_train  \
# 0  Prediction markets are financial markets, but ...
# 1  When we form opinions on topics, the depth of ...
# 2  Some futurist philosophers have recently becom...
#
#                                               y_pred  \
# 0  But the way they are structured, they have no ...
# 1  So, in our thinking, we often do not do the mo...
# 2  …\nThe third step, which I call “achieving our...
#
#                                               y_test
# 0  More accurate stock prices better achieve this...
# 1  Thinking-for-yourself, however, has a big prob...
# 2  … We can’t rely on our current institutions an...
# Processed Sincerity Adds To Drift.txt from Robin Hanson
# (4, 5)
#          Author                                    Title  \
# 0  Robin Hanson         Elite-Only Financial Markets.txt
# 1  Robin Hanson            Thinkers Must Be Heretics.txt
# 2  Robin Hanson  ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3  Robin Hanson              Sincerity Adds To Drift.txt
#
#                                              y_train  \
# 0  Prediction markets are financial markets, but ...
# 1  When we form opinions on topics, the depth of ...
# 2  Some futurist philosophers have recently becom...
# 3  The 2008 book Ritual and Its Consequences: An ...
#
#                                               y_pred  \
# 0  But the way they are structured, they have no ...
# 1  So, in our thinking, we often do not do the mo...
# 2  …\nThe third step, which I call “achieving our...
# 3  They are not questions about the object of the...
#
#                                               y_test
# 0  More accurate stock prices better achieve this...
# 1  Thinking-for-yourself, however, has a big prob...
# 2  … We can’t rely on our current institutions an...
# 3  After three decades of marriage, kids, laundry...
# Processed Sacred Inquiry.txt from Robin Hanson
# (5, 5)
#          Author                                    Title  \
# 0  Robin Hanson         Elite-Only Financial Markets.txt
# 1  Robin Hanson            Thinkers Must Be Heretics.txt
# 2  Robin Hanson  ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3  Robin Hanson              Sincerity Adds To Drift.txt
# 4  Robin Hanson                       Sacred Inquiry.txt
#
#                                              y_train  \
# 0  Prediction markets are financial markets, but ...
# 1  When we form opinions on topics, the depth of ...
# 2  Some futurist philosophers have recently becom...
# 3  The 2008 book Ritual and Its Consequences: An ...
# 4  The reason I first started to study the sacred...
#
#                                               y_pred  \
# 0  But the way they are structured, they have no ...
# 1  So, in our thinking, we often do not do the mo...
# 2  …\nThe third step, which I call “achieving our...
# 3  They are not questions about the object of the...
# 4  I feel that I must not only respect but also r...
#
#                                               y_test
# 0  More accurate stock prices better achieve this...
# 1  Thinking-for-yourself, however, has a big prob...
# 2  … We can’t rely on our current institutions an...
# 3  After three decades of marriage, kids, laundry...
# 4  I don’t calculate most of this; it instead com...
# Processed My Status Circles.txt from Robin Hanson
# (6, 5)
#          Author                                    Title  \
# 0  Robin Hanson         Elite-Only Financial Markets.txt
# 1  Robin Hanson            Thinkers Must Be Heretics.txt
# 2  Robin Hanson  ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3  Robin Hanson              Sincerity Adds To Drift.txt
# 4  Robin Hanson                       Sacred Inquiry.txt
# 5  Robin Hanson                    My Status Circles.txt
#
#                                              y_train  \
# 0  Prediction markets are financial markets, but ...
# 1  When we form opinions on topics, the depth of ...
# 2  Some futurist philosophers have recently becom...
# 3  The 2008 book Ritual and Its Consequences: An ...
# 4  The reason I first started to study the sacred...
# 5  Most of us have circles of concern, where we c...
#
#                                               y_pred  \
# 0  But the way they are structured, they have no ...
# 1  So, in our thinking, we often do not do the mo...
# 2  …\nThe third step, which I call “achieving our...
# 3  They are not questions about the object of the...
# 4  I feel that I must not only respect but also r...
# 5  In this post I want to talk about my circles o...
#
#                                               y_test
# 0  More accurate stock prices better achieve this...
# 1  Thinking-for-yourself, however, has a big prob...
# 2  … We can’t rely on our current institutions an...
# 3  After three decades of marriage, kids, laundry...
# 4  I don’t calculate most of this; it instead com...
# 5  (For small practical innovations, the situatio...
# Processed Cycles of War & Empire.txt from Robin Hanson
# (7, 5)
#          Author                                    Title  \
# 0  Robin Hanson         Elite-Only Financial Markets.txt
# 1  Robin Hanson            Thinkers Must Be Heretics.txt
# 2  Robin Hanson  ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3  Robin Hanson              Sincerity Adds To Drift.txt
# 4  Robin Hanson                       Sacred Inquiry.txt
# 5  Robin Hanson                    My Status Circles.txt
# 6  Robin Hanson               Cycles of War & Empire.txt
#
#                                              y_train  \
# 0  Prediction markets are financial markets, but ...
# 1  When we form opinions on topics, the depth of ...
# 2  Some futurist philosophers have recently becom...
# 3  The 2008 book Ritual and Its Consequences: An ...
# 4  The reason I first started to study the sacred...
# 5  Most of us have circles of concern, where we c...
# 6  I’ve just read five of Peter Turchin’s books: ...
#
#                                               y_pred  \
# 0  But the way they are structured, they have no ...
# 1  So, in our thinking, we often do not do the mo...
# 2  …\nThe third step, which I call “achieving our...
# 3  They are not questions about the object of the...
# 4  I feel that I must not only respect but also r...
# 5  In this post I want to talk about my circles o...
# 6  So far, I can’t see a clear, direct contradict...
#
#                                               y_test
# 0  More accurate stock prices better achieve this...
# 1  Thinking-for-yourself, however, has a big prob...
# 2  … We can’t rely on our current institutions an...
# 3  After three decades of marriage, kids, laundry...
# 4  I don’t calculate most of this; it instead com...
# 5  (For small practical innovations, the situatio...
# 6  First there’s war success and a growing area a...
# Processed Kaczynski’s Collapse Theory.txt from Robin Hanson
# (8, 5)
#          Author                                    Title  \
# 0  Robin Hanson         Elite-Only Financial Markets.txt
# 1  Robin Hanson            Thinkers Must Be Heretics.txt
# 2  Robin Hanson  ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3  Robin Hanson              Sincerity Adds To Drift.txt
# 4  Robin Hanson                       Sacred Inquiry.txt
# 5  Robin Hanson                    My Status Circles.txt
# 6  Robin Hanson               Cycles of War & Empire.txt
# 7  Robin Hanson          Kaczynski’s Collapse Theory.txt
#
#                                              y_train  \
# 0  Prediction markets are financial markets, but ...
# 1  When we form opinions on topics, the depth of ...
# 2  Some futurist philosophers have recently becom...
# 3  The 2008 book Ritual and Its Consequences: An ...
# 4  The reason I first started to study the sacred...
# 5  Most of us have circles of concern, where we c...
# 6  I’ve just read five of Peter Turchin’s books: ...
# 7  Many people argue that we should beware of for...
#
#                                               y_pred  \
# 0  But the way they are structured, they have no ...
# 1  So, in our thinking, we often do not do the mo...
# 2  …\nThe third step, which I call “achieving our...
# 3  They are not questions about the object of the...
# 4  I feel that I must not only respect but also r...
# 5  In this post I want to talk about my circles o...
# 6  So far, I can’t see a clear, direct contradict...
# 7  So Kaczynski’s theory seems to me to be more o...
#
#                                               y_test
# 0  More accurate stock prices better achieve this...
# 1  Thinking-for-yourself, however, has a big prob...
# 2  … We can’t rely on our current institutions an...
# 3  After three decades of marriage, kids, laundry...
# 4  I don’t calculate most of this; it instead com...
# 5  (For small practical innovations, the situatio...
# 6  First there’s war success and a growing area a...
# 7  And yet we’ve never even seen a factor of two ...
# Processed Specific vs. General Foragers & Farmers.txt from Robin Hanson
# (9, 5)
#          Author                                        Title  \
# 0  Robin Hanson             Elite-Only Financial Markets.txt
# 1  Robin Hanson                Thinkers Must Be Heretics.txt
# 2  Robin Hanson      ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3  Robin Hanson                  Sincerity Adds To Drift.txt
# 4  Robin Hanson                           Sacred Inquiry.txt
# 5  Robin Hanson                        My Status Circles.txt
# 6  Robin Hanson                   Cycles of War & Empire.txt
# 7  Robin Hanson              Kaczynski’s Collapse Theory.txt
# 8  Robin Hanson  Specific vs. General Foragers & Farmers.txt
#
#                                              y_train  \
# 0  Prediction markets are financial markets, but ...
# 1  When we form opinions on topics, the depth of ...
# 2  Some futurist philosophers have recently becom...
# 3  The 2008 book Ritual and Its Consequences: An ...
# 4  The reason I first started to study the sacred...
# 5  Most of us have circles of concern, where we c...
# 6  I’ve just read five of Peter Turchin’s books: ...
# 7  Many people argue that we should beware of for...
# 8  Scott Alexander in 2013:\nRightism is what hap...
#
#                                               y_pred  \
# 0  But the way they are structured, they have no ...
# 1  So, in our thinking, we often do not do the mo...
# 2  …\nThe third step, which I call “achieving our...
# 3  They are not questions about the object of the...
# 4  I feel that I must not only respect but also r...
# 5  In this post I want to talk about my circles o...
# 6  So far, I can’t see a clear, direct contradict...
# 7  So Kaczynski’s theory seems to me to be more o...
# 8  The forager-farmer model is, in part, an expla...
#
#                                               y_test
# 0  More accurate stock prices better achieve this...
# 1  Thinking-for-yourself, however, has a big prob...
# 2  … We can’t rely on our current institutions an...
# 3  After three decades of marriage, kids, laundry...
# 4  I don’t calculate most of this; it instead com...
# 5  (For small practical innovations, the situatio...
# 6  First there’s war success and a growing area a...
# 7  And yet we’ve never even seen a factor of two ...
# 8  Specific farming norms were typically effectiv...
# Processed Futarchy Details.txt from Robin Hanson
# (10, 5)
#          Author                                        Title  \
# 0  Robin Hanson             Elite-Only Financial Markets.txt
# 1  Robin Hanson                Thinkers Must Be Heretics.txt
# 2  Robin Hanson      ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3  Robin Hanson                  Sincerity Adds To Drift.txt
# 4  Robin Hanson                           Sacred Inquiry.txt
# 5  Robin Hanson                        My Status Circles.txt
# 6  Robin Hanson                   Cycles of War & Empire.txt
# 7  Robin Hanson              Kaczynski’s Collapse Theory.txt
# 8  Robin Hanson  Specific vs. General Foragers & Farmers.txt
# 9  Robin Hanson                         Futarchy Details.txt
#
#                                              y_train  \
# 0  Prediction markets are financial markets, but ...
# 1  When we form opinions on topics, the depth of ...
# 2  Some futurist philosophers have recently becom...
# 3  The 2008 book Ritual and Its Consequences: An ...
# 4  The reason I first started to study the sacred...
# 5  Most of us have circles of concern, where we c...
# 6  I’ve just read five of Peter Turchin’s books: ...
# 7  Many people argue that we should beware of for...
# 8  Scott Alexander in 2013:\nRightism is what hap...
# 9  I started to write on prediction markets, whic...
#
#                                               y_pred  \
# 0  But the way they are structured, they have no ...
# 1  So, in our thinking, we often do not do the mo...
# 2  …\nThe third step, which I call “achieving our...
# 3  They are not questions about the object of the...
# 4  I feel that I must not only respect but also r...
# 5  In this post I want to talk about my circles o...
# 6  So far, I can’t see a clear, direct contradict...
# 7  So Kaczynski’s theory seems to me to be more o...
# 8  The forager-farmer model is, in part, an expla...
# 9  But the cost is worth it for the accuracy. So,...
#
#                                               y_test
# 0  More accurate stock prices better achieve this...
# 1  Thinking-for-yourself, however, has a big prob...
# 2  … We can’t rely on our current institutions an...
# 3  After three decades of marriage, kids, laundry...
# 4  I don’t calculate most of this; it instead com...
# 5  (For small practical innovations, the situatio...
# 6  First there’s war success and a growing area a...
# 7  And yet we’ve never even seen a factor of two ...
# 8  Specific farming norms were typically effectiv...
# 9  Some academics have focused on a related probl...
# Processed Even When Contrarians Win, They Lose.txt from Robin Hanson
# (11, 5)
#           Author                                        Title  \
# 0   Robin Hanson             Elite-Only Financial Markets.txt
# 1   Robin Hanson                Thinkers Must Be Heretics.txt
# 2   Robin Hanson      ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3   Robin Hanson                  Sincerity Adds To Drift.txt
# 4   Robin Hanson                           Sacred Inquiry.txt
# 5   Robin Hanson                        My Status Circles.txt
# 6   Robin Hanson                   Cycles of War & Empire.txt
# 7   Robin Hanson              Kaczynski’s Collapse Theory.txt
# 8   Robin Hanson  Specific vs. General Foragers & Farmers.txt
# 9   Robin Hanson                         Futarchy Details.txt
# 10  Robin Hanson     Even When Contrarians Win, They Lose.txt
#
#                                               y_train  \
# 0   Prediction markets are financial markets, but ...
# 1   When we form opinions on topics, the depth of ...
# 2   Some futurist philosophers have recently becom...
# 3   The 2008 book Ritual and Its Consequences: An ...
# 4   The reason I first started to study the sacred...
# 5   Most of us have circles of concern, where we c...
# 6   I’ve just read five of Peter Turchin’s books: ...
# 7   Many people argue that we should beware of for...
# 8   Scott Alexander in 2013:\nRightism is what hap...
# 9   I started to write on prediction markets, whic...
# 10  Imagine two people at a fork in the road of id...
#
#                                                y_pred  \
# 0   But the way they are structured, they have no ...
# 1   So, in our thinking, we often do not do the mo...
# 2   …\nThe third step, which I call “achieving our...
# 3   They are not questions about the object of the...
# 4   I feel that I must not only respect but also r...
# 5   In this post I want to talk about my circles o...
# 6   So far, I can’t see a clear, direct contradict...
# 7   So Kaczynski’s theory seems to me to be more o...
# 8   The forager-farmer model is, in part, an expla...
# 9   But the cost is worth it for the accuracy. So,...
# 10  This is the "prestige effect."\nSo, the person...
#
#                                                y_test
# 0   More accurate stock prices better achieve this...
# 1   Thinking-for-yourself, however, has a big prob...
# 2   … We can’t rely on our current institutions an...
# 3   After three decades of marriage, kids, laundry...
# 4   I don’t calculate most of this; it instead com...
# 5   (For small practical innovations, the situatio...
# 6   First there’s war success and a growing area a...
# 7   And yet we’ve never even seen a factor of two ...
# 8   Specific farming norms were typically effectiv...
# 9   Some academics have focused on a related probl...
# 10  People will prefer to cite his publications as...
# Processed To Oppose Polarization, Tug Sideways.txt from Robin Hanson
# (12, 5)
#           Author                                        Title  \
# 0   Robin Hanson             Elite-Only Financial Markets.txt
# 1   Robin Hanson                Thinkers Must Be Heretics.txt
# 2   Robin Hanson      ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3   Robin Hanson                  Sincerity Adds To Drift.txt
# 4   Robin Hanson                           Sacred Inquiry.txt
# 5   Robin Hanson                        My Status Circles.txt
# 6   Robin Hanson                   Cycles of War & Empire.txt
# 7   Robin Hanson              Kaczynski’s Collapse Theory.txt
# 8   Robin Hanson  Specific vs. General Foragers & Farmers.txt
# 9   Robin Hanson                         Futarchy Details.txt
# 10  Robin Hanson     Even When Contrarians Win, They Lose.txt
# 11  Robin Hanson     To Oppose Polarization, Tug Sideways.txt
#
#                                               y_train  \
# 0   Prediction markets are financial markets, but ...
# 1   When we form opinions on topics, the depth of ...
# 2   Some futurist philosophers have recently becom...
# 3   The 2008 book Ritual and Its Consequences: An ...
# 4   The reason I first started to study the sacred...
# 5   Most of us have circles of concern, where we c...
# 6   I’ve just read five of Peter Turchin’s books: ...
# 7   Many people argue that we should beware of for...
# 8   Scott Alexander in 2013:\nRightism is what hap...
# 9   I started to write on prediction markets, whic...
# 10  Imagine two people at a fork in the road of id...
# 11  Just over 42% of the people in each party view...
#
#                                                y_pred  \
# 0   But the way they are structured, they have no ...
# 1   So, in our thinking, we often do not do the mo...
# 2   …\nThe third step, which I call “achieving our...
# 3   They are not questions about the object of the...
# 4   I feel that I must not only respect but also r...
# 5   In this post I want to talk about my circles o...
# 6   So far, I can’t see a clear, direct contradict...
# 7   So Kaczynski’s theory seems to me to be more o...
# 8   The forager-farmer model is, in part, an expla...
# 9   But the cost is worth it for the accuracy. So,...
# 10  This is the "prestige effect."\nSo, the person...
# 11  That is, to pull the rope in a direction that ...
#
#                                                y_test
# 0   More accurate stock prices better achieve this...
# 1   Thinking-for-yourself, however, has a big prob...
# 2   … We can’t rely on our current institutions an...
# 3   After three decades of marriage, kids, laundry...
# 4   I don’t calculate most of this; it instead com...
# 5   (For small practical innovations, the situatio...
# 6   First there’s war success and a growing area a...
# 7   And yet we’ve never even seen a factor of two ...
# 8   Specific farming norms were typically effectiv...
# 9   Some academics have focused on a related probl...
# 10  People will prefer to cite his publications as...
# 11  That is, take positions that are perpendicular...
# Processed Honing Fertility Fall Theories.txt from Robin Hanson
# (13, 5)
#           Author                                        Title  \
# 0   Robin Hanson             Elite-Only Financial Markets.txt
# 1   Robin Hanson                Thinkers Must Be Heretics.txt
# 2   Robin Hanson      ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3   Robin Hanson                  Sincerity Adds To Drift.txt
# 4   Robin Hanson                           Sacred Inquiry.txt
# 5   Robin Hanson                        My Status Circles.txt
# 6   Robin Hanson                   Cycles of War & Empire.txt
# 7   Robin Hanson              Kaczynski’s Collapse Theory.txt
# 8   Robin Hanson  Specific vs. General Foragers & Farmers.txt
# 9   Robin Hanson                         Futarchy Details.txt
# 10  Robin Hanson     Even When Contrarians Win, They Lose.txt
# 11  Robin Hanson     To Oppose Polarization, Tug Sideways.txt
# 12  Robin Hanson           Honing Fertility Fall Theories.txt
#
#                                               y_train  \
# 0   Prediction markets are financial markets, but ...
# 1   When we form opinions on topics, the depth of ...
# 2   Some futurist philosophers have recently becom...
# 3   The 2008 book Ritual and Its Consequences: An ...
# 4   The reason I first started to study the sacred...
# 5   Most of us have circles of concern, where we c...
# 6   I’ve just read five of Peter Turchin’s books: ...
# 7   Many people argue that we should beware of for...
# 8   Scott Alexander in 2013:\nRightism is what hap...
# 9   I started to write on prediction markets, whic...
# 10  Imagine two people at a fork in the road of id...
# 11  Just over 42% of the people in each party view...
# 12  Richard Hanania has done me the honor of caref...
#
#                                                y_pred  \
# 0   But the way they are structured, they have no ...
# 1   So, in our thinking, we often do not do the mo...
# 2   …\nThe third step, which I call “achieving our...
# 3   They are not questions about the object of the...
# 4   I feel that I must not only respect but also r...
# 5   In this post I want to talk about my circles o...
# 6   So far, I can’t see a clear, direct contradict...
# 7   So Kaczynski’s theory seems to me to be more o...
# 8   The forager-farmer model is, in part, an expla...
# 9   But the cost is worth it for the accuracy. So,...
# 10  This is the "prestige effect."\nSo, the person...
# 11  That is, to pull the rope in a direction that ...
# 12  So we copy them, which gives us more kids. Wai...
#
#                                                y_test
# 0   More accurate stock prices better achieve this...
# 1   Thinking-for-yourself, however, has a big prob...
# 2   … We can’t rely on our current institutions an...
# 3   After three decades of marriage, kids, laundry...
# 4   I don’t calculate most of this; it instead com...
# 5   (For small practical innovations, the situatio...
# 6   First there’s war success and a growing area a...
# 7   And yet we’ve never even seen a factor of two ...
# 8   Specific farming norms were typically effectiv...
# 9   Some academics have focused on a related probl...
# 10  People will prefer to cite his publications as...
# 11  That is, take positions that are perpendicular...
# 12  … As for why this limited fertility norm has o...
# Processed Comparing Income & Sex Redistribution.txt from Robin Hanson
# (14, 5)
#           Author                                        Title  \
# 0   Robin Hanson             Elite-Only Financial Markets.txt
# 1   Robin Hanson                Thinkers Must Be Heretics.txt
# 2   Robin Hanson      ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3   Robin Hanson                  Sincerity Adds To Drift.txt
# 4   Robin Hanson                           Sacred Inquiry.txt
# 5   Robin Hanson                        My Status Circles.txt
# 6   Robin Hanson                   Cycles of War & Empire.txt
# 7   Robin Hanson              Kaczynski’s Collapse Theory.txt
# 8   Robin Hanson  Specific vs. General Foragers & Farmers.txt
# 9   Robin Hanson                         Futarchy Details.txt
# 10  Robin Hanson     Even When Contrarians Win, They Lose.txt
# 11  Robin Hanson     To Oppose Polarization, Tug Sideways.txt
# 12  Robin Hanson           Honing Fertility Fall Theories.txt
# 13  Robin Hanson    Comparing Income & Sex Redistribution.txt
#
#                                               y_train  \
# 0   Prediction markets are financial markets, but ...
# 1   When we form opinions on topics, the depth of ...
# 2   Some futurist philosophers have recently becom...
# 3   The 2008 book Ritual and Its Consequences: An ...
# 4   The reason I first started to study the sacred...
# 5   Most of us have circles of concern, where we c...
# 6   I’ve just read five of Peter Turchin’s books: ...
# 7   Many people argue that we should beware of for...
# 8   Scott Alexander in 2013:\nRightism is what hap...
# 9   I started to write on prediction markets, whic...
# 10  Imagine two people at a fork in the road of id...
# 11  Just over 42% of the people in each party view...
# 12  Richard Hanania has done me the honor of caref...
# 13  Disclaimer: This post is on sensitive topics o...
#
#                                                y_pred  \
# 0   But the way they are structured, they have no ...
# 1   So, in our thinking, we often do not do the mo...
# 2   …\nThe third step, which I call “achieving our...
# 3   They are not questions about the object of the...
# 4   I feel that I must not only respect but also r...
# 5   In this post I want to talk about my circles o...
# 6   So far, I can’t see a clear, direct contradict...
# 7   So Kaczynski’s theory seems to me to be more o...
# 8   The forager-farmer model is, in part, an expla...
# 9   But the cost is worth it for the accuracy. So,...
# 10  This is the "prestige effect."\nSo, the person...
# 11  That is, to pull the rope in a direction that ...
# 12  So we copy them, which gives us more kids. Wai...
# 13  For sex, the situation is similar, but even mo...
#
#                                                y_test
# 0   More accurate stock prices better achieve this...
# 1   Thinking-for-yourself, however, has a big prob...
# 2   … We can’t rely on our current institutions an...
# 3   After three decades of marriage, kids, laundry...
# 4   I don’t calculate most of this; it instead com...
# 5   (For small practical innovations, the situatio...
# 6   First there’s war success and a growing area a...
# 7   And yet we’ve never even seen a factor of two ...
# 8   Specific farming norms were typically effectiv...
# 9   Some academics have focused on a related probl...
# 10  People will prefer to cite his publications as...
# 11  That is, take positions that are perpendicular...
# 12  … As for why this limited fertility norm has o...
# 13  Even so, when arguing about policy, people oft...
# Processed Sacred Distance Hides Motives.txt from Robin Hanson
# (15, 5)
#           Author                                        Title  \
# 0   Robin Hanson             Elite-Only Financial Markets.txt
# 1   Robin Hanson                Thinkers Must Be Heretics.txt
# 2   Robin Hanson      ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3   Robin Hanson                  Sincerity Adds To Drift.txt
# 4   Robin Hanson                           Sacred Inquiry.txt
# 5   Robin Hanson                        My Status Circles.txt
# 6   Robin Hanson                   Cycles of War & Empire.txt
# 7   Robin Hanson              Kaczynski’s Collapse Theory.txt
# 8   Robin Hanson  Specific vs. General Foragers & Farmers.txt
# 9   Robin Hanson                         Futarchy Details.txt
# 10  Robin Hanson     Even When Contrarians Win, They Lose.txt
# 11  Robin Hanson     To Oppose Polarization, Tug Sideways.txt
# 12  Robin Hanson           Honing Fertility Fall Theories.txt
# 13  Robin Hanson    Comparing Income & Sex Redistribution.txt
# 14  Robin Hanson            Sacred Distance Hides Motives.txt
#
#                                               y_train  \
# 0   Prediction markets are financial markets, but ...
# 1   When we form opinions on topics, the depth of ...
# 2   Some futurist philosophers have recently becom...
# 3   The 2008 book Ritual and Its Consequences: An ...
# 4   The reason I first started to study the sacred...
# 5   Most of us have circles of concern, where we c...
# 6   I’ve just read five of Peter Turchin’s books: ...
# 7   Many people argue that we should beware of for...
# 8   Scott Alexander in 2013:\nRightism is what hap...
# 9   I started to write on prediction markets, whic...
# 10  Imagine two people at a fork in the road of id...
# 11  Just over 42% of the people in each party view...
# 12  Richard Hanania has done me the honor of caref...
# 13  Disclaimer: This post is on sensitive topics o...
# 14  My book with Kevin Simler describes many hidde...
#
#                                                y_pred  \
# 0   But the way they are structured, they have no ...
# 1   So, in our thinking, we often do not do the mo...
# 2   …\nThe third step, which I call “achieving our...
# 3   They are not questions about the object of the...
# 4   I feel that I must not only respect but also r...
# 5   In this post I want to talk about my circles o...
# 6   So far, I can’t see a clear, direct contradict...
# 7   So Kaczynski’s theory seems to me to be more o...
# 8   The forager-farmer model is, in part, an expla...
# 9   But the cost is worth it for the accuracy. So,...
# 10  This is the "prestige effect."\nSo, the person...
# 11  That is, to pull the rope in a direction that ...
# 12  So we copy them, which gives us more kids. Wai...
# 13  For sex, the situation is similar, but even mo...
# 14  But when we have abstract concepts that we hav...
#
#                                                y_test
# 0   More accurate stock prices better achieve this...
# 1   Thinking-for-yourself, however, has a big prob...
# 2   … We can’t rely on our current institutions an...
# 3   After three decades of marriage, kids, laundry...
# 4   I don’t calculate most of this; it instead com...
# 5   (For small practical innovations, the situatio...
# 6   First there’s war success and a growing area a...
# 7   And yet we’ve never even seen a factor of two ...
# 8   Specific farming norms were typically effectiv...
# 9   Some academics have focused on a related probl...
# 10  People will prefer to cite his publications as...
# 11  That is, take positions that are perpendicular...
# 12  … As for why this limited fertility norm has o...
# 13  Even so, when arguing about policy, people oft...
# 14  But we ground other more “sacred” abstract con...
# Processed Agency Failure AI Apocalypse_.txt from Robin Hanson
# (16, 5)
#           Author                                        Title  \
# 0   Robin Hanson             Elite-Only Financial Markets.txt
# 1   Robin Hanson                Thinkers Must Be Heretics.txt
# 2   Robin Hanson      ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3   Robin Hanson                  Sincerity Adds To Drift.txt
# 4   Robin Hanson                           Sacred Inquiry.txt
# 5   Robin Hanson                        My Status Circles.txt
# 6   Robin Hanson                   Cycles of War & Empire.txt
# 7   Robin Hanson              Kaczynski’s Collapse Theory.txt
# 8   Robin Hanson  Specific vs. General Foragers & Farmers.txt
# 9   Robin Hanson                         Futarchy Details.txt
# 10  Robin Hanson     Even When Contrarians Win, They Lose.txt
# 11  Robin Hanson     To Oppose Polarization, Tug Sideways.txt
# 12  Robin Hanson           Honing Fertility Fall Theories.txt
# 13  Robin Hanson    Comparing Income & Sex Redistribution.txt
# 14  Robin Hanson            Sacred Distance Hides Motives.txt
# 15  Robin Hanson            Agency Failure AI Apocalypse_.txt
#
#                                               y_train  \
# 0   Prediction markets are financial markets, but ...
# 1   When we form opinions on topics, the depth of ...
# 2   Some futurist philosophers have recently becom...
# 3   The 2008 book Ritual and Its Consequences: An ...
# 4   The reason I first started to study the sacred...
# 5   Most of us have circles of concern, where we c...
# 6   I’ve just read five of Peter Turchin’s books: ...
# 7   Many people argue that we should beware of for...
# 8   Scott Alexander in 2013:\nRightism is what hap...
# 9   I started to write on prediction markets, whic...
# 10  Imagine two people at a fork in the road of id...
# 11  Just over 42% of the people in each party view...
# 12  Richard Hanania has done me the honor of caref...
# 13  Disclaimer: This post is on sensitive topics o...
# 14  My book with Kevin Simler describes many hidde...
# 15  Years ago my ex-co-blogger Eliezer Yudkowsky a...
#
#                                                y_pred  \
# 0   But the way they are structured, they have no ...
# 1   So, in our thinking, we often do not do the mo...
# 2   …\nThe third step, which I call “achieving our...
# 3   They are not questions about the object of the...
# 4   I feel that I must not only respect but also r...
# 5   In this post I want to talk about my circles o...
# 6   So far, I can’t see a clear, direct contradict...
# 7   So Kaczynski’s theory seems to me to be more o...
# 8   The forager-farmer model is, in part, an expla...
# 9   But the cost is worth it for the accuracy. So,...
# 10  This is the "prestige effect."\nSo, the person...
# 11  That is, to pull the rope in a direction that ...
# 12  So we copy them, which gives us more kids. Wai...
# 13  For sex, the situation is similar, but even mo...
# 14  But when we have abstract concepts that we hav...
# 15  … The process will be a bit slow, but it’s the...
#
#                                                y_test
# 0   More accurate stock prices better achieve this...
# 1   Thinking-for-yourself, however, has a big prob...
# 2   … We can’t rely on our current institutions an...
# 3   After three decades of marriage, kids, laundry...
# 4   I don’t calculate most of this; it instead com...
# 5   (For small practical innovations, the situatio...
# 6   First there’s war success and a growing area a...
# 7   And yet we’ve never even seen a factor of two ...
# 8   Specific farming norms were typically effectiv...
# 9   Some academics have focused on a related probl...
# 10  People will prefer to cite his publications as...
# 11  That is, take positions that are perpendicular...
# 12  … As for why this limited fertility norm has o...
# 13  Even so, when arguing about policy, people oft...
# 14  But we ground other more “sacred” abstract con...
# 15  Law enforcement will drive down complaints and...
# Processed Are We A Tower of Babel_.txt from Robin Hanson
# (17, 5)
#           Author                                        Title  \
# 0   Robin Hanson             Elite-Only Financial Markets.txt
# 1   Robin Hanson                Thinkers Must Be Heretics.txt
# 2   Robin Hanson      ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3   Robin Hanson                  Sincerity Adds To Drift.txt
# 4   Robin Hanson                           Sacred Inquiry.txt
# 5   Robin Hanson                        My Status Circles.txt
# 6   Robin Hanson                   Cycles of War & Empire.txt
# 7   Robin Hanson              Kaczynski’s Collapse Theory.txt
# 8   Robin Hanson  Specific vs. General Foragers & Farmers.txt
# 9   Robin Hanson                         Futarchy Details.txt
# 10  Robin Hanson     Even When Contrarians Win, They Lose.txt
# 11  Robin Hanson     To Oppose Polarization, Tug Sideways.txt
# 12  Robin Hanson           Honing Fertility Fall Theories.txt
# 13  Robin Hanson    Comparing Income & Sex Redistribution.txt
# 14  Robin Hanson            Sacred Distance Hides Motives.txt
# 15  Robin Hanson            Agency Failure AI Apocalypse_.txt
# 16  Robin Hanson                 Are We A Tower of Babel_.txt
#
#                                               y_train  \
# 0   Prediction markets are financial markets, but ...
# 1   When we form opinions on topics, the depth of ...
# 2   Some futurist philosophers have recently becom...
# 3   The 2008 book Ritual and Its Consequences: An ...
# 4   The reason I first started to study the sacred...
# 5   Most of us have circles of concern, where we c...
# 6   I’ve just read five of Peter Turchin’s books: ...
# 7   Many people argue that we should beware of for...
# 8   Scott Alexander in 2013:\nRightism is what hap...
# 9   I started to write on prediction markets, whic...
# 10  Imagine two people at a fork in the road of id...
# 11  Just over 42% of the people in each party view...
# 12  Richard Hanania has done me the honor of caref...
# 13  Disclaimer: This post is on sensitive topics o...
# 14  My book with Kevin Simler describes many hidde...
# 15  Years ago my ex-co-blogger Eliezer Yudkowsky a...
# 16  And the whole earth was of one language, and o...
#
#                                                y_pred  \
# 0   But the way they are structured, they have no ...
# 1   So, in our thinking, we often do not do the mo...
# 2   …\nThe third step, which I call “achieving our...
# 3   They are not questions about the object of the...
# 4   I feel that I must not only respect but also r...
# 5   In this post I want to talk about my circles o...
# 6   So far, I can’t see a clear, direct contradict...
# 7   So Kaczynski’s theory seems to me to be more o...
# 8   The forager-farmer model is, in part, an expla...
# 9   But the cost is worth it for the accuracy. So,...
# 10  This is the "prestige effect."\nSo, the person...
# 11  That is, to pull the rope in a direction that ...
# 12  So we copy them, which gives us more kids. Wai...
# 13  For sex, the situation is similar, but even mo...
# 14  But when we have abstract concepts that we hav...
# 15  … The process will be a bit slow, but it’s the...
# 16  But he’s not so evil that he would kill everyo...
#
#                                                y_test
# 0   More accurate stock prices better achieve this...
# 1   Thinking-for-yourself, however, has a big prob...
# 2   … We can’t rely on our current institutions an...
# 3   After three decades of marriage, kids, laundry...
# 4   I don’t calculate most of this; it instead com...
# 5   (For small practical innovations, the situatio...
# 6   First there’s war success and a growing area a...
# 7   And yet we’ve never even seen a factor of two ...
# 8   Specific farming norms were typically effectiv...
# 9   Some academics have focused on a related probl...
# 10  People will prefer to cite his publications as...
# 11  That is, take positions that are perpendicular...
# 12  … As for why this limited fertility norm has o...
# 13  Even so, when arguing about policy, people oft...
# 14  But we ground other more “sacred” abstract con...
# 15  Law enforcement will drive down complaints and...
# 16  The God of the Christian New Testament did mor...
# Processed Why Not For-Profit Government_.txt from Robin Hanson
# (18, 5)
#           Author                                        Title  \
# 0   Robin Hanson             Elite-Only Financial Markets.txt
# 1   Robin Hanson                Thinkers Must Be Heretics.txt
# 2   Robin Hanson      ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3   Robin Hanson                  Sincerity Adds To Drift.txt
# 4   Robin Hanson                           Sacred Inquiry.txt
# 5   Robin Hanson                        My Status Circles.txt
# 6   Robin Hanson                   Cycles of War & Empire.txt
# 7   Robin Hanson              Kaczynski’s Collapse Theory.txt
# 8   Robin Hanson  Specific vs. General Foragers & Farmers.txt
# 9   Robin Hanson                         Futarchy Details.txt
# 10  Robin Hanson     Even When Contrarians Win, They Lose.txt
# 11  Robin Hanson     To Oppose Polarization, Tug Sideways.txt
# 12  Robin Hanson           Honing Fertility Fall Theories.txt
# 13  Robin Hanson    Comparing Income & Sex Redistribution.txt
# 14  Robin Hanson            Sacred Distance Hides Motives.txt
# 15  Robin Hanson            Agency Failure AI Apocalypse_.txt
# 16  Robin Hanson                 Are We A Tower of Babel_.txt
# 17  Robin Hanson           Why Not For-Profit Government_.txt
#
#                                               y_train  \
# 0   Prediction markets are financial markets, but ...
# 1   When we form opinions on topics, the depth of ...
# 2   Some futurist philosophers have recently becom...
# 3   The 2008 book Ritual and Its Consequences: An ...
# 4   The reason I first started to study the sacred...
# 5   Most of us have circles of concern, where we c...
# 6   I’ve just read five of Peter Turchin’s books: ...
# 7   Many people argue that we should beware of for...
# 8   Scott Alexander in 2013:\nRightism is what hap...
# 9   I started to write on prediction markets, whic...
# 10  Imagine two people at a fork in the road of id...
# 11  Just over 42% of the people in each party view...
# 12  Richard Hanania has done me the honor of caref...
# 13  Disclaimer: This post is on sensitive topics o...
# 14  My book with Kevin Simler describes many hidde...
# 15  Years ago my ex-co-blogger Eliezer Yudkowsky a...
# 16  And the whole earth was of one language, and o...
# 17  Centuries ago, most commerce and production wa...
#
#                                                y_pred  \
# 0   But the way they are structured, they have no ...
# 1   So, in our thinking, we often do not do the mo...
# 2   …\nThe third step, which I call “achieving our...
# 3   They are not questions about the object of the...
# 4   I feel that I must not only respect but also r...
# 5   In this post I want to talk about my circles o...
# 6   So far, I can’t see a clear, direct contradict...
# 7   So Kaczynski’s theory seems to me to be more o...
# 8   The forager-farmer model is, in part, an expla...
# 9   But the cost is worth it for the accuracy. So,...
# 10  This is the "prestige effect."\nSo, the person...
# 11  That is, to pull the rope in a direction that ...
# 12  So we copy them, which gives us more kids. Wai...
# 13  For sex, the situation is similar, but even mo...
# 14  But when we have abstract concepts that we hav...
# 15  … The process will be a bit slow, but it’s the...
# 16  But he’s not so evil that he would kill everyo...
# 17  In this world, the government is a for-profit ...
#
#                                                y_test
# 0   More accurate stock prices better achieve this...
# 1   Thinking-for-yourself, however, has a big prob...
# 2   … We can’t rely on our current institutions an...
# 3   After three decades of marriage, kids, laundry...
# 4   I don’t calculate most of this; it instead com...
# 5   (For small practical innovations, the situatio...
# 6   First there’s war success and a growing area a...
# 7   And yet we’ve never even seen a factor of two ...
# 8   Specific farming norms were typically effectiv...
# 9   Some academics have focused on a related probl...
# 10  People will prefer to cite his publications as...
# 11  That is, take positions that are perpendicular...
# 12  … As for why this limited fertility norm has o...
# 13  Even so, when arguing about policy, people oft...
# 14  But we ground other more “sacred” abstract con...
# 15  Law enforcement will drive down complaints and...
# 16  The God of the Christian New Testament did mor...
# 17  … It’s not uncommon for corpocracies in fictio...
# Processed We Add Near, Average Far.txt from Robin Hanson
# (19, 5)
#           Author                                        Title  \
# 0   Robin Hanson             Elite-Only Financial Markets.txt
# 1   Robin Hanson                Thinkers Must Be Heretics.txt
# 2   Robin Hanson      ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3   Robin Hanson                  Sincerity Adds To Drift.txt
# 4   Robin Hanson                           Sacred Inquiry.txt
# 5   Robin Hanson                        My Status Circles.txt
# 6   Robin Hanson                   Cycles of War & Empire.txt
# 7   Robin Hanson              Kaczynski’s Collapse Theory.txt
# 8   Robin Hanson  Specific vs. General Foragers & Farmers.txt
# 9   Robin Hanson                         Futarchy Details.txt
# 10  Robin Hanson     Even When Contrarians Win, They Lose.txt
# 11  Robin Hanson     To Oppose Polarization, Tug Sideways.txt
# 12  Robin Hanson           Honing Fertility Fall Theories.txt
# 13  Robin Hanson    Comparing Income & Sex Redistribution.txt
# 14  Robin Hanson            Sacred Distance Hides Motives.txt
# 15  Robin Hanson            Agency Failure AI Apocalypse_.txt
# 16  Robin Hanson                 Are We A Tower of Babel_.txt
# 17  Robin Hanson           Why Not For-Profit Government_.txt
# 18  Robin Hanson                 We Add Near, Average Far.txt
#
#                                               y_train  \
# 0   Prediction markets are financial markets, but ...
# 1   When we form opinions on topics, the depth of ...
# 2   Some futurist philosophers have recently becom...
# 3   The 2008 book Ritual and Its Consequences: An ...
# 4   The reason I first started to study the sacred...
# 5   Most of us have circles of concern, where we c...
# 6   I’ve just read five of Peter Turchin’s books: ...
# 7   Many people argue that we should beware of for...
# 8   Scott Alexander in 2013:\nRightism is what hap...
# 9   I started to write on prediction markets, whic...
# 10  Imagine two people at a fork in the road of id...
# 11  Just over 42% of the people in each party view...
# 12  Richard Hanania has done me the honor of caref...
# 13  Disclaimer: This post is on sensitive topics o...
# 14  My book with Kevin Simler describes many hidde...
# 15  Years ago my ex-co-blogger Eliezer Yudkowsky a...
# 16  And the whole earth was of one language, and o...
# 17  Centuries ago, most commerce and production wa...
# 18  Quick, what is the best gift you ever got from...
#
#                                                y_pred  \
# 0   But the way they are structured, they have no ...
# 1   So, in our thinking, we often do not do the mo...
# 2   …\nThe third step, which I call “achieving our...
# ...
# 4    I feel that I must not only respect but also r...
# ..                                                 ...
# 132  In such cases, the official policy is not in t...
# 133  There would be a few very advanced AI systems,...
# 134  So the more grabby a civ is, the more likely t...
# 135  These services are, in the language of Drexler...
# 136  So, the prior is actually not that different f...
#
#                                                 y_test
# 0    More accurate stock prices better achieve this...
# 1    Thinking-for-yourself, however, has a big prob...
# 2    … We can’t rely on our current institutions an...
# 3    After three decades of marriage, kids, laundry...
# 4    I don’t calculate most of this; it instead com...
# ..                                                 ...
# 132  Similarly, official medical advisors tend to a...
# 133  AI systems wouldn’t work equally well with all...
# 134  In which case, the boundary at which different...
# 135  … Even applications of AI within autonomous sy...
# 136  Even though actual median planet lifetime is 5...
#
# [137 rows x 5 columns]
# Processed Prestige in US Today.txt from Robin Hanson
# (138, 5)
#            Author                                          Title  \
# 0    Robin Hanson               Elite-Only Financial Markets.txt
# 1    Robin Hanson                  Thinkers Must Be Heretics.txt
# 2    Robin Hanson        ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3    Robin Hanson                    Sincerity Adds To Drift.txt
# 4    Robin Hanson                             Sacred Inquiry.txt
# ..            ...                                            ...
# 133  Robin Hanson                              AGI Is Sacred.txt
# 134  Robin Hanson                     An Alien War Nightmare.txt
# 135  Robin Hanson                     How Lumpy AI Services_.txt
# 136  Robin Hanson  Cook’s Critique of Our Earliness Argument.txt
# 137  Robin Hanson                       Prestige in US Today.txt
#
#                                                y_train  \
# 0    Prediction markets are financial markets, but ...
# 1    When we form opinions on topics, the depth of ...
# 2    Some futurist philosophers have recently becom...
# 3    The 2008 book Ritual and Its Consequences: An ...
# 4    The reason I first started to study the sacred...
# ..                                                 ...
# 133  Sacred things are especially valuable, sharply...
# 134  Grabby aliens are advanced civs who change the...
# 135  Long ago people like Marx and Engels predicted...
# 136  Tristan Cook has posted an impressive analysis...
# 137  Lauren A. Rivera’s Pedigree: How Elite Student...
#
#                                                 y_pred  \
# 0    But the way they are structured, they have no ...
# 1    So, in our thinking, we often do not do the mo...
# 2    …\nThe third step, which I call “achieving our...
# 3    They are not questions about the object of the...
# 4    I feel that I must not only respect but also r...
# ..                                                 ...
# 133  There would be a few very advanced AI systems,...
# 134  So the more grabby a civ is, the more likely t...
# 135  These services are, in the language of Drexler...
# 136  So, the prior is actually not that different f...
# 137  So, this is a system that is self-reinforcing,...
#
#                                                 y_test
# 0    More accurate stock prices better achieve this...
# 1    Thinking-for-yourself, however, has a big prob...
# 2    … We can’t rely on our current institutions an...
# 3    After three decades of marriage, kids, laundry...
# 4    I don’t calculate most of this; it instead com...
# ..                                                 ...
# 133  AI systems wouldn’t work equally well with all...
# 134  In which case, the boundary at which different...
# 135  … Even applications of AI within autonomous sy...
# 136  Even though actual median planet lifetime is 5...
# 137  It seems that while these firms do sell concre...
#
# [138 rows x 5 columns]
# Processed AI Risk, Again.txt from Robin Hanson
# (139, 5)
#            Author                                          Title  \
# 0    Robin Hanson               Elite-Only Financial Markets.txt
# 1    Robin Hanson                  Thinkers Must Be Heretics.txt
# 2    Robin Hanson        ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3    Robin Hanson                    Sincerity Adds To Drift.txt
# 4    Robin Hanson                             Sacred Inquiry.txt
# ..            ...                                            ...
# 134  Robin Hanson                     An Alien War Nightmare.txt
# 135  Robin Hanson                     How Lumpy AI Services_.txt
# 136  Robin Hanson  Cook’s Critique of Our Earliness Argument.txt
# 137  Robin Hanson                       Prestige in US Today.txt
# 138  Robin Hanson                             AI Risk, Again.txt
#
#                                                y_train  \
# 0    Prediction markets are financial markets, but ...
# 1    When we form opinions on topics, the depth of ...
# 2    Some futurist philosophers have recently becom...
# 3    The 2008 book Ritual and Its Consequences: An ...
# 4    The reason I first started to study the sacred...
# ..                                                 ...
# 134  Grabby aliens are advanced civs who change the...
# 135  Long ago people like Marx and Engels predicted...
# 136  Tristan Cook has posted an impressive analysis...
# 137  Lauren A. Rivera’s Pedigree: How Elite Student...
# 138  Large language models like ChatGPT have recent...
#
#                                                 y_pred  \
# 0    But the way they are structured, they have no ...
# 1    So, in our thinking, we often do not do the mo...
# 2    …\nThe third step, which I call “achieving our...
# 3    They are not questions about the object of the...
# 4    I feel that I must not only respect but also r...
# ..                                                 ...
# 134  So the more grabby a civ is, the more likely t...
# 135  These services are, in the language of Drexler...
# 136  So, the prior is actually not that different f...
# 137  So, this is a system that is self-reinforcing,...
# 138  (The future world could be a world of many AIs...
#
#                                                 y_test
# 0    More accurate stock prices better achieve this...
# 1    Thinking-for-yourself, however, has a big prob...
# 2    … We can’t rely on our current institutions an...
# 3    After three decades of marriage, kids, laundry...
# 4    I don’t calculate most of this; it instead com...
# ..                                                 ...
# 134  In which case, the boundary at which different...
# 135  … Even applications of AI within autonomous sy...
# 136  Even though actual median planet lifetime is 5...
# 137  It seems that while these firms do sell concre...
# 138  Of course the owners of such future ventures, ...
#
# [139 rows x 5 columns]
# Processed New Tax Career Agent Test.txt from Robin Hanson
# (140, 5)
#            Author                                          Title  \
# 0    Robin Hanson               Elite-Only Financial Markets.txt
# 1    Robin Hanson                  Thinkers Must Be Heretics.txt
# 2    Robin Hanson        ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3    Robin Hanson                    Sincerity Adds To Drift.txt
# 4    Robin Hanson                             Sacred Inquiry.txt
# ..            ...                                            ...
# 135  Robin Hanson                     How Lumpy AI Services_.txt
# 136  Robin Hanson  Cook’s Critique of Our Earliness Argument.txt
# 137  Robin Hanson                       Prestige in US Today.txt
# 138  Robin Hanson                             AI Risk, Again.txt
# 139  Robin Hanson                  New Tax Career Agent Test.txt
#
#                                                y_train  \
# 0    Prediction markets are financial markets, but ...
# 1    When we form opinions on topics, the depth of ...
# 2    Some futurist philosophers have recently becom...
# 3    The 2008 book Ritual and Its Consequences: An ...
# 4    The reason I first started to study the sacred...
# ..                                                 ...
# 135  Long ago people like Marx and Engels predicted...
# 136  Tristan Cook has posted an impressive analysis...
# 137  Lauren A. Rivera’s Pedigree: How Elite Student...
# 138  Large language models like ChatGPT have recent...
# 139  If that taxpayer approved, the taxes that he o...
#
#                                                 y_pred  \
# 0    But the way they are structured, they have no ...
# 1    So, in our thinking, we often do not do the mo...
# 2    …\nThe third step, which I call “achieving our...
# 3    They are not questions about the object of the...
# 4    I feel that I must not only respect but also r...
# ..                                                 ...
# 135  These services are, in the language of Drexler...
# 136  So, the prior is actually not that different f...
# 137  So, this is a system that is self-reinforcing,...
# 138  (The future world could be a world of many AIs...
# 139  If the worker who gets the TCA has a higher ex...
#
#                                                 y_test
# 0    More accurate stock prices better achieve this...
# 1    Thinking-for-yourself, however, has a big prob...
# 2    … We can’t rely on our current institutions an...
# 3    After three decades of marriage, kids, laundry...
# 4    I don’t calculate most of this; it instead com...
# ..                                                 ...
# 135  … Even applications of AI within autonomous sy...
# 136  Even though actual median planet lifetime is 5...
# 137  It seems that while these firms do sell concre...
# 138  Of course the owners of such future ventures, ...
# 139  Bids should give direct estimates of worker va...
#
# [140 rows x 5 columns]
# Processed A Perfect Storm of Inflexibility.txt from Robin Hanson
# (141, 5)
#            Author                                          Title  \
# 0    Robin Hanson               Elite-Only Financial Markets.txt
# 1    Robin Hanson                  Thinkers Must Be Heretics.txt
# 2    Robin Hanson        ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3    Robin Hanson                    Sincerity Adds To Drift.txt
# 4    Robin Hanson                             Sacred Inquiry.txt
# ..            ...                                            ...
# 136  Robin Hanson  Cook’s Critique of Our Earliness Argument.txt
# 137  Robin Hanson                       Prestige in US Today.txt
# 138  Robin Hanson                             AI Risk, Again.txt
# 139  Robin Hanson                  New Tax Career Agent Test.txt
# 140  Robin Hanson           A Perfect Storm of Inflexibility.txt
#
#                                                y_train  \
# 0    Prediction markets are financial markets, but ...
# 1    When we form opinions on topics, the depth of ...
# 2    Some futurist philosophers have recently becom...
# 3    The 2008 book Ritual and Its Consequences: An ...
# 4    The reason I first started to study the sacred...
# ..                                                 ...
# 136  Tristan Cook has posted an impressive analysis...
# 137  Lauren A. Rivera’s Pedigree: How Elite Student...
# 138  Large language models like ChatGPT have recent...
# 139  If that taxpayer approved, the taxes that he o...
# 140  Most biological species specialize for particu...
#
#                                                 y_pred  \
# 0    But the way they are structured, they have no ...
# 1    So, in our thinking, we often do not do the mo...
# 2    …\nThe third step, which I call “achieving our...
# 3    They are not questions about the object of the...
# 4    I feel that I must not only respect but also r...
# ..                                                 ...
# 136  So, the prior is actually not that different f...
# 137  So, this is a system that is self-reinforcing,...
# 138  (The future world could be a world of many AIs...
# 139  If the worker who gets the TCA has a higher ex...
# 140  But the problem is that, in peace time, this m...
#
#                                                 y_test
# 0    More accurate stock prices better achieve this...
# 1    Thinking-for-yourself, however, has a big prob...
# 2    … We can’t rely on our current institutions an...
# 3    After three decades of marriage, kids, laundry...
# 4    I don’t calculate most of this; it instead com...
# ..                                                 ...
# 136  Even though actual median planet lifetime is 5...
# 137  It seems that while these firms do sell concre...
# 138  Of course the owners of such future ventures, ...
# 139  Bids should give direct estimates of worker va...
# 140  In addition to these two considerations, longe...
#
# [141 rows x 5 columns]
# Processed Culture Policy Is Neglected.txt from Robin Hanson
# (142, 5)
#            Author                                    Title  \
# 0    Robin Hanson         Elite-Only Financial Markets.txt
# 1    Robin Hanson            Thinkers Must Be Heretics.txt
# 2    Robin Hanson  ‘Long Reflection’ Is Crazy Bad Idea.txt
# 3    Robin Hanson              Sincerity Adds To Drift.txt
# 4    Robin Hanson                       Sacred Inquiry.txt
# ..            ...                                      ...
# 137  Robin Hanson                 Prestige in US Today.txt
# 138  Robin Hanson                       AI Risk, Again.txt
# 139  Robin Hanson            New Tax Career Agent Test.txt
# 140  Robin Hanson     A Perfect Storm of Inflexibility.txt
# 141  Robin Hanson          Culture Policy Is Neglected.txt
#
#                                                y_train  \
# 0    Prediction markets are financial markets, but ...
# 1    When we form opinions on topics, the depth of ...
# 2    Some futurist philosophers have recently becom...
# 3    The 2008 book Ritual and Its Consequences: An ...
# 4    The reason I first started to study the sacred...
# ..                                                 ...
# 137  Lauren A. Rivera’s Pedigree: How Elite Student...
# 138  Large language models like ChatGPT have recent...
# 139  If that taxpayer approved, the taxes that he o...
# 140  Most biological species specialize for particu...
# 141  Long ago in physics I learned of the Union of ...
#
#                                                 y_pred  \
# 0    But the way they are structured, they have no ...
# 1    So, in our thinking, we often do not do the mo...
# 2    …\nThe third step, which I call “achieving our...
# 3    They are not questions about the object of the...
# 4    I feel that I must not only respect but also r...
# ..                                                 ...
# 137  So, this is a system that is self-reinforcing,...
# 138  (The future world could be a world of many AIs...
# 139  If the worker who gets the TCA has a higher ex...
# 140  But the problem is that, in peace time, this m...
# 141  But in the current case, the demographic trans...
#
#                                                 y_test
# 0    More accurate stock prices better achieve this...
# 1    Thinking-for-yourself, however, has a big prob...
# 2    … We can’t rely on our current institutions an...
# 3    After three decades of marriage, kids, laundry...
# 4    I don’t calculate most of this; it instead com...
# ..                                                 ...
# 137  It seems that while these firms do sell concre...
# 138  Of course the owners of such future ventures, ...
# 139  Bids should give direct estimates of worker va...
# 140  In addition to these two considerations, longe...
# 141  So if we could go back to Tenochtitlan or Rome...
#
# [142 rows x 5 columns]

# %%
result = pd.concat([df, hanson], axis=0)
result
# Out:
#            Author                                  Title  \
# 0      Mark_Twain  THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1      Mark_Twain  To the Person Sitting in Darkness.txt
# 2      Mark_Twain            Life on the Mississippi.txt
# 3      Mark_Twain           KING LEOPOLD’S SOLILOQUY.txt
# 4      Mark_Twain                     A Horse's Tale.txt
# ..            ...                                    ...
# 137  Robin Hanson               Prestige in US Today.txt
# 138  Robin Hanson                     AI Risk, Again.txt
# 139  Robin Hanson          New Tax Career Agent Test.txt
# 140  Robin Hanson   A Perfect Storm of Inflexibility.txt
# 141  Robin Hanson        Culture Policy Is Neglected.txt
#
#                                                y_train  \
# 0    THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1    TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2    Produced by David Widger. Earliest PG text edi...
# 3    KING LEOPOLD’S SOLILOQUY\n\n\n\n\n            ...
# 4    A Horse’s Tale\n\n\n                          ...
# ..                                                 ...
# 137  Lauren A. Rivera’s Pedigree: How Elite Student...
# 138  Large language models like ChatGPT have recent...
# 139  If that taxpayer approved, the taxes that he o...
# 140  Most biological species specialize for particu...
# 141  Long ago in physics I learned of the Union of ...
#
#                                                 y_pred  \
# 0    He made a\ntrip to Hadleyburg and found it the...
# 1    And\nthere is more of it. The People who Sit i...
# 2    A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3    They\nare saying that I have a secret, a secre...
# 4    * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# ..                                                 ...
# 137  So, this is a system that is self-reinforcing,...
# 138  (The future world could be a world of many AIs...
# 139  If the worker who gets the TCA has a higher ex...
# 140  But the problem is that, in peace time, this m...
# 141  But in the current case, the demographic trans...
#
#                                                 y_test
# 0    joy. He began to form a plan at once, saying t...
# 1    Game. It shows that these new players of it ar...
# 2    rd. CHAPTER XXIII. Old French Settlements.--We...
# 3    hen uttered against a king. Miscreants—they ar...
# 4    rian will correct these defects.” The cats in ...
# ..                                                 ...
# 137  It seems that while these firms do sell concre...
# 138  Of course the owners of such future ventures, ...
# 139  Bids should give direct estimates of worker va...
# 140  In addition to these two considerations, longe...
# 141  So if we could go back to Tenochtitlan or Rome...
#
# [520 rows x 5 columns]

# %%
df = result.copy()
def word_count(text):
    return len(str(text).split())

# Calculate word count for each column
df['y_train_word_count'] = df['y_train'].apply(word_count)
df['y_test_word_count'] = df['y_test'].apply(word_count)

# Sum the word counts
df['total_word_count'] = df['y_train_word_count'] + df['y_test_word_count']

# Filter the DataFrame
filtered_df = df[df['total_word_count'] >= 900]
filtered_df
# Out:
#            Author                                              Title  \
# 0      Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1      Mark_Twain              To the Person Sitting in Darkness.txt
# 2      Mark_Twain                        Life on the Mississippi.txt
# 4      Mark_Twain                                 A Horse's Tale.txt
# 5      Mark_Twain  1601 Conversation as it was by the Social Fire...
# ..            ...                                                ...
# 137  Robin Hanson                           Prestige in US Today.txt
# 138  Robin Hanson                                 AI Risk, Again.txt
# 139  Robin Hanson                      New Tax Career Agent Test.txt
# 140  Robin Hanson               A Perfect Storm of Inflexibility.txt
# 141  Robin Hanson                    Culture Policy Is Neglected.txt
#
#                                                y_train  \
# 0    THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1    TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2    Produced by David Widger. Earliest PG text edi...
# 4    A Horse’s Tale\n\n\n                          ...
# 5    1601\n\nConversation as it was by the Social F...
# ..                                                 ...
# 137  Lauren A. Rivera’s Pedigree: How Elite Student...
# 138  Large language models like ChatGPT have recent...
# 139  If that taxpayer approved, the taxes that he o...
# 140  Most biological species specialize for particu...
# 141  Long ago in physics I learned of the Union of ...
#
#                                                 y_pred  \
# 0    He made a\ntrip to Hadleyburg and found it the...
# 1    And\nthere is more of it. The People who Sit i...
# 2    A New Plan.--A Little Tact.--The Mayor is\nHir...
# 4    * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 5    The first edition of it was published\nin 1880...
# ..                                                 ...
# 137  So, this is a system that is self-reinforcing,...
# 138  (The future world could be a world of many AIs...
# 139  If the worker who gets the TCA has a higher ex...
# 140  But the problem is that, in peace time, this m...
# 141  But in the current case, the demographic trans...
#
#                                                 y_test  y_train_word_count  \
# 0    joy. He began to form a plan at once, saying t...                 474
# 1    Game. It shows that these new players of it ar...                 500
# 2    rd. CHAPTER XXIII. Old French Settlements.--We...                 500
# 4    rian will correct these defects.” The cats in ...                 496
# 5    601. The piece is a supposititious conversatio...                 470
# ..                                                 ...                 ...
# 137  It seems that while these firms do sell concre...                 487
# 138  Of course the owners of such future ventures, ...                 481
# 139  Bids should give direct estimates of worker va...                 482
# 140  In addition to these two considerations, longe...                 479
# 141  So if we could go back to Tenochtitlan or Rome...                 498
#
#      y_test_word_count  total_word_count
# 0                  500               974
# 1                  500              1000
# 2                  500              1000
# 4                  500               996
# 5                  500               970
# ..                 ...               ...
# 137                500               987
# 138                500               981
# 139                500               982
# 140                500               979
# 141                500               998
#
# [398 rows x 8 columns]

# %%
filtered_df.to_csv("final_dataset.csv", index=None)

# %%
nlp_results.to_csv("txt_results.csv", index=None)

# %% [markdown]
# ### N-grams

# %%
df = pd.read_csv("final_dataset.csv")

# %%
df.head()
# Out:
#        Author                                              Title  \
# 0  Mark_Twain              THE MAN THAT CORRUPTED HADLEYBURG.txt
# 1  Mark_Twain              To the Person Sitting in Darkness.txt
# 2  Mark_Twain                        Life on the Mississippi.txt
# 3  Mark_Twain                                 A Horse's Tale.txt
# 4  Mark_Twain  1601 Conversation as it was by the Social Fire...
#
#                                              y_train  \
# 0  THE MAN THAT CORRUPTED HADLEYBURG\n\nAND OTHER...
# 1  TO THE PERSON SITTING IN DARKNESS\n\n\n       ...
# 2  Produced by David Widger. Earliest PG text edi...
# 3  A Horse’s Tale\n\n\n                          ...
# 4  1601\n\nConversation as it was by the Social F...
#
#                                               y_pred  \
# 0  He made a\ntrip to Hadleyburg and found it the...
# 1  And\nthere is more of it. The People who Sit i...
# 2  A New Plan.--A Little Tact.--The Mayor is\nHir...
# 3  * * * * *\n\n\nA Horse’s Tale\n\nCHAP. I.\nSOL...
# 4  The first edition of it was published\nin 1880...
#
#                                               y_test  y_train_word_count  \
# 0  joy. He began to form a plan at once, saying t...                 474
# 1  Game. It shows that these new players of it ar...                 500
# 2  rd. CHAPTER XXIII. Old French Settlements.--We...                 500
# 3  rian will correct these defects.” The cats in ...                 496
# 4  601. The piece is a supposititious conversatio...                 470
#
#    y_test_word_count  total_word_count
# 0                500               974
# 1                500              1000
# 2                500              1000
# 3                500               996
# 4                500               970

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from nltk.util import ngrams
from nltk.tokenize import word_tokenize
import nltk

nltk.download('punkt')

# Function to get n-grams as sets
def extract_ngrams(text, n):
    tokens = word_tokenize(text.lower())
    return set(ngrams(tokens, n))

# Function to compare n-grams
def count_common_ngrams(row, n, col1, col2):
    pred_ngrams = extract_ngrams(row[col1], n)
    test_ngrams = extract_ngrams(row[col2], n)
    return len(pred_ngrams & test_ngrams)

# Apply on DataFrame
df['common_unigrams_y_pred_test'] = df.apply(lambda row: count_common_ngrams(row, 1, "y_pred", "y_test"), axis=1)
df['common_bigrams_y_pred_test'] = df.apply(lambda row: count_common_ngrams(row, 2, "y_pred", "y_test"), axis=1)
df['common_trigrams_y_pred_test'] = df.apply(lambda row: count_common_ngrams(row, 3, "y_pred", "y_test"), axis=1)

df['common_unigrams_y_pred_train'] = df.apply(lambda row: count_common_ngrams(row, 1, "y_pred", "y_train"), axis=1)
df['common_bigrams_y_pred_train'] = df.apply(lambda row: count_common_ngrams(row, 2, "y_pred", "y_train"), axis=1)
df['common_trigrams_y_pred_train'] = df.apply(lambda row: count_common_ngrams(row, 3, "y_pred", "y_train"), axis=1)

df['common_unigrams_y_test_train'] = df.apply(lambda row: count_common_ngrams(row, 1, "y_test", "y_train"), axis=1)
df['common_bigrams_y_test_train'] = df.apply(lambda row: count_common_ngrams(row, 2, "y_test", "y_train"), axis=1)
df['common_trigrams_y_test_train'] = df.apply(lambda row: count_common_ngrams(row, 3, "y_test", "y_train"), axis=1)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/Konstantinos/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df.drop(columns=["y_train_word_count","y_test_word_count", "total_word_count"], inplace=True)

# %% [markdown]
# In natural language processing (NLP), n-grams are contiguous sequences of n items (typically words) extracted from a given text. They are widely used for tasks involving text comparison, language modeling, and evaluation of generated content.
#
# Unigrams are single words. Comparing unigrams between predicted and reference texts helps evaluate basic word-level agreement, which is useful for assessing vocabulary overlap.
#
# Bigrams are two-word sequences. Matching bigrams capture basic word ordering and local syntactic structure.
#
# Trigrams, three-word sequences, provide deeper insight into fluency and phrase-level coherence.
#
# In this project, we count the number of shared unigrams, bigrams, and trigrams between predicted texts (y_pred) and ground-truth references (y_test) for each row in the dataset. This allows us to quantify not just the lexical similarity but also how well the predicted text preserves short- and medium-range word sequences from the original.

# %%
columns_to_average = [
    'common_unigrams_y_pred_test',
    'common_unigrams_y_pred_train',
    'common_unigrams_y_test_train',
    'common_bigrams_y_pred_test',
    'common_bigrams_y_pred_train',
    'common_bigrams_y_test_train',
    'common_trigrams_y_pred_test',
    'common_trigrams_y_pred_train',
    'common_trigrams_y_test_train'
]

# Print mean of each column
for col in columns_to_average:
    mean_val = df[col].mean()
    print(f"Mean of {col}: {mean_val:.2f}")
# Out:
# Mean of common_unigrams_y_pred_test: 51.43
# Mean of common_unigrams_y_pred_train: 57.65
# Mean of common_unigrams_y_test_train: 92.05
# Mean of common_bigrams_y_pred_test: 29.80
# Mean of common_bigrams_y_pred_train: 38.87
# Mean of common_bigrams_y_test_train: 47.82
# Mean of common_trigrams_y_pred_test: 6.61
# Mean of common_trigrams_y_pred_train: 12.70
# Mean of common_trigrams_y_test_train: 11.32

# %% [markdown]
# The comparison of shared n-grams among the predicted texts (y_pred), the ground-truth test texts (y_test), and the training texts (y_train) provides insight into how well the model captures both the reference and learned linguistic patterns.
#
# y_pred vs y_test:
# The mean common n-gram counts between y_pred and y_test decrease as the n-gram size increases (51.43 unigrams → 29.80 bigrams → 6.61 trigrams). This pattern is expected, as longer n-grams are more sensitive to word order and exact phrasing. The relatively low trigram overlap indicates that while the model captures many of the correct words, it may struggle with producing fluent or precise phrasing.
#
# y_pred vs y_train:
# The model shows higher overlap with the training data (e.g., 57.65 unigrams, 38.87 bigrams, 12.70 trigrams), suggesting a degree of memorization or strong influence from the training corpus. This may be especially noticeable if the training data contains repeated or template-like structures.
#
# y_test vs y_train:
# The highest overlap is observed here, particularly at the unigram level (92.05), implying that the test set shares a significant amount of vocabulary and phrase patterns with the training set. This lexical similarity could contribute to the model’s ability to generalize, but also raises considerations about potential data leakage or insufficient domain separation.
#
# Overall, the decreasing trend across n-gram sizes is typical and reflects increasing strictness of the match. The relatively low trigram overlap with y_test underscores the difficulty in generating coherent and exact sequences, while the higher similarity with y_train highlights the model’s reliance on seen data.

# %% [markdown]
# 🔹 Unigrams:
# Highest overlap: y_test vs y_train (92.05), indicating strong vocabulary similarity between the test and training sets.
#
# The model (y_pred) shares more unigrams with the training set (57.65) than with the test set (51.43), suggesting it draws heavily from the training vocabulary.
#
# Overall, the unigram results show the model is reasonably effective at using the correct words, but not as strongly as the overlap found within the data itself.
#
# 🔹 Bigrams:
# Bigram overlap follows a similar trend but decreases across all pairs due to increased word-order sensitivity.
#
# y_pred vs y_train (38.87) > y_test vs y_train (47.82) > y_pred vs y_test (29.80), implying the model better captures short local sequences from training than it reproduces the exact phrasing in the test set.
#
# 🔹 Trigrams:
# The sharpest drop is seen here, with the lowest value for y_pred vs y_test (6.61).
#
# y_pred vs y_train (12.70) is still the highest, indicating the model is most confident in reproducing learned multi-word phrases rather than generating new coherent ones.
#
# y_test vs y_train (11.32) being higher than y_pred vs y_test confirms that the test set contains many longer sequences also found in training, but the model struggles to regenerate them precisely.
#
# ✅ Summary
# The model performs best when replicating content from the training data, particularly in longer n-grams.
#
# Exact matches with the test set degrade as n-gram size increases, highlighting difficulties with fluency and precise word ordering.
#
# The high overlap between y_test and y_train across all n-gram levels suggests that the test set is not fully independent, which may affect evaluation and generalization insights.

# %% [markdown]
# ### All Metrics

# %%
import pandas as pd
import numpy as np
import re
import string
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
# from sentence_transformers import SentenceTransformer
from nltk.util import ngrams
from nltk.corpus import stopwords
import spacy.cli
import nltk
nltk.download("stopwords")
spacy.cli.download("en_core_web_sm")

df = pd.read_csv("txt_results.csv")
df["y_pred"] = df["y_pred"].astype(str)
df["y_test"] = df["y_test"].astype(str)

nlp = spacy.load("en_core_web_sm")

stop_words = set(stopwords.words('english'))
# transformer = SentenceTransformer('all-MiniLM-L6-v2')

def get_ngrams(text, n):
    tokens = text.split()
    return set(ngrams(tokens, n))

def pos_similarity(doc1, doc2):
    pos1 = [token.pos_ for token in doc1]
    pos2 = [token.pos_ for token in doc2]
    return len(set(pos1) & set(pos2)) / max(len(set(pos1 + pos2)), 1)

def tense_similarity(doc1, doc2, tense):
    tags = {
        "Past": ["VBD", "VBN"],
        "Present": ["VBP", "VBZ", "VBG"],
        "Future": ["MD"]
    }
    doc1_tags = [token.tag_ for token in doc1 if token.tag_ in tags[tense]]
    doc2_tags = [token.tag_ for token in doc2 if token.tag_ in tags[tense]]
    return min(len(doc1_tags), len(doc2_tags)) / max(len(doc1_tags + doc2_tags), 1)

def stopword_similarity(doc1, doc2):
    sw1 = [token.text for token in doc1 if token.text.lower() in stop_words]
    sw2 = [token.text for token in doc2 if token.text.lower() in stop_words]
    return len(set(sw1) & set(sw2)) / max(len(set(sw1 + sw2)), 1)

def punctuation_count(text, mark):
    return text.count(mark)

def tfidf_score(s1, s2):
    vect = TfidfVectorizer().fit([s1, s2])
    tfidf = vect.transform([s1, s2])
    return cosine_similarity(tfidf[0], tfidf[1])[0][0]

# def transformer_similarity(s1, s2):
#     emb = transformer.encode([s1, s2])
#     return cosine_similarity([emb[0]], [emb[1]])[0][0]

def compare_texts(row):
    pred, truth = row['y_pred'], row['y_test']
    doc1, doc2 = nlp(pred), nlp(truth)
    
    return pd.Series({
        "Text Similarity": doc1.similarity(doc2),
        "POS Similarity": pos_similarity(doc1, doc2),
        "TfIdf Score": tfidf_score(pred, truth),
        "Bigram Overlap": len(get_ngrams(pred, 2) & get_ngrams(truth, 2)),
        "Trigram Overlap": len(get_ngrams(pred, 3) & get_ngrams(truth, 3)),
        # "Transformer Similarity": transformer_similarity(pred, truth),
        "Sentence Length Similarity": min(len(pred), len(truth)) / max(len(pred), len(truth)),
        "Sentence Length Variance": abs(len(pred) - len(truth)),
        "Verb Tense Similarity (Past)": tense_similarity(doc1, doc2, "Past"),
        "Verb Tense Similarity (Present)": tense_similarity(doc1, doc2, "Present"),
        "Verb Tense Similarity (Future)": tense_similarity(doc1, doc2, "Future"),
        "Verb Tense Analysis Total": sum([
            tense_similarity(doc1, doc2, "Past"),
            tense_similarity(doc1, doc2, "Present"),
            tense_similarity(doc1, doc2, "Future")
        ]),
        "Stop Words Usage Similarity": stopword_similarity(doc1, doc2),
        "Question Mark Count": int('?' in pred) == int('?' in truth),
        "Punctuation Count": sum(pred.count(p) for p in string.punctuation),
        "Comma Count": punctuation_count(pred, ','),
        "Em Dash Count": punctuation_count(pred, '—'),
    })

# Assuming df has 'y_pred' and 'y_test'
import nltk
nltk.download('stopwords')
nltk.download('punkt')

results = df.apply(compare_texts, axis=1)
final_df = pd.concat([df, results], axis=1)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Konstantinos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 55.4 MB/s eta 0:00:00a 0:00:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Konstantinos/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/Konstantinos/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# /var/folders/bh/r76cgybj5_3flr0fxd2cx4040000gp/T/ipykernel_6114/1611109876.py:66: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
#   "Text Similarity": doc1.similarity(doc2),
